# %%
import sys
sys.path.append('..')

from baselines.cnn.trainer import Trainer
# Out:
# c:\Users\iwama\Desktop\Maciej\Eng\meteoapp-data\venv\lib\site-packages\gribapi\__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.27.0
#   warnings.warn(

# %%
trainer = Trainer()

# %%
trainer.train(1000)
# Out:
# Epoch 1/1000:
# Train Loss: 0.1456, Last LR: 0.0010
# Val Loss: 0.1279
# ---------
# Epoch 2/1000:
# Train Loss: 0.1166, Last LR: 0.0010
# Val Loss: 0.1167
# ---------
# Epoch 3/1000:
# Train Loss: 0.1094, Last LR: 0.0010
# Val Loss: 0.1135
# ---------
# Epoch 4/1000:
# Train Loss: 0.1068, Last LR: 0.0010
# Val Loss: 0.1124
# ---------
# Epoch 5/1000:
# Train Loss: 0.1045, Last LR: 0.0010
# Val Loss: 0.1108
# ---------
# Epoch 6/1000:
# Train Loss: 0.1029, Last LR: 0.0010
# Val Loss: 0.1102
# ---------
# Epoch 7/1000:
# Train Loss: 0.1019, Last LR: 0.0010
# Val Loss: 0.1101
# ---------
# Epoch 8/1000:
# Train Loss: 0.1012, Last LR: 0.0010
# Val Loss: 0.1102
# ---------
# Epoch 9/1000:
# Train Loss: 0.1006, Last LR: 0.0010
# Val Loss: 0.1099
# ---------
# Epoch 10/1000:
# Train Loss: 0.1002, Last LR: 0.0010
# Val Loss: 0.1103
# ---------
# Epoch 11/1000:
# Train Loss: 0.0998, Last LR: 0.0010
# Val Loss: 0.1097
# ---------
# Epoch 12/1000:
# Train Loss: 0.0994, Last LR: 0.0010
# Val Loss: 0.1094
# ---------
# Epoch 13/1000:
# Train Loss: 0.0989, Last LR: 0.0010
# Val Loss: 0.1091
# ---------
# Epoch 14/1000:
# Train Loss: 0.0986, Last LR: 0.0010
# Val Loss: 0.1087
# ---------
# Epoch 15/1000:
# Train Loss: 0.0983, Last LR: 0.0010
# Val Loss: 0.1084
# ---------
# Epoch 16/1000:
# Train Loss: 0.0979, Last LR: 0.0010
# Val Loss: 0.1079
# ---------
# Epoch 17/1000:
# Train Loss: 0.0977, Last LR: 0.0010
# Val Loss: 0.1078
# ---------
# Epoch 18/1000:
# Train Loss: 0.0973, Last LR: 0.0010
# Val Loss: 0.1077
# ---------
# Epoch 19/1000:
# Train Loss: 0.0969, Last LR: 0.0010
# Val Loss: 0.1076
# ---------
# Epoch 20/1000:
# Train Loss: 0.0967, Last LR: 0.0010
# Val Loss: 0.1077
# ---------
# Epoch 21/1000:
# Train Loss: 0.0966, Last LR: 0.0010
# Val Loss: 0.1074
# ---------
# Epoch 22/1000:
# Train Loss: 0.0965, Last LR: 0.0010
# Val Loss: 0.1070
# ---------
# Epoch 23/1000:
# Train Loss: 0.0960, Last LR: 0.0010
# Val Loss: 0.1070
# ---------
# Epoch 24/1000:
# Train Loss: 0.0960, Last LR: 0.0010
# Val Loss: 0.1067
# ---------
# Epoch 25/1000:
# Train Loss: 0.0955, Last LR: 0.0010
# Val Loss: 0.1066
# ---------
# Epoch 26/1000:
# Train Loss: 0.0955, Last LR: 0.0010
# Val Loss: 0.1064
# ---------
# Epoch 27/1000:
# Train Loss: 0.0954, Last LR: 0.0010
# Val Loss: 0.1060
# ---------
# Epoch 28/1000:
# Train Loss: 0.0948, Last LR: 0.0010
# Val Loss: 0.1066
# ---------
# Epoch 29/1000:
# Train Loss: 0.0946, Last LR: 0.0010
# Val Loss: 0.1064
# ---------
# Epoch 30/1000:
# Train Loss: 0.0945, Last LR: 0.0010
# Val Loss: 0.1064
# ---------
# Epoch 31/1000:
# Train Loss: 0.0944, Last LR: 0.0010
# Val Loss: 0.1062
# ---------
# Epoch 32/1000:
# Train Loss: 0.0940, Last LR: 0.0010
# Val Loss: 0.1065
# ---------
# Epoch 33/1000:
# Train Loss: 0.0941, Last LR: 0.0010
# Val Loss: 0.1058
# ---------
# Epoch 34/1000:
# Train Loss: 0.0942, Last LR: 0.0010
# Val Loss: 0.1058
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 35/1000:
# Train Loss: 0.0908, Last LR: 0.0005
# Val Loss: 0.1020
# ---------
# Epoch 36/1000:
# Train Loss: 0.0904, Last LR: 0.0005
# Val Loss: 0.1022
# ---------
# Epoch 37/1000:
# Train Loss: 0.0902, Last LR: 0.0005
# Val Loss: 0.1021
# ---------
# Epoch 38/1000:
# Train Loss: 0.0901, Last LR: 0.0005
# Val Loss: 0.1022
# ---------
# Epoch 39/1000:
# Train Loss: 0.0903, Last LR: 0.0005
# Val Loss: 0.1022
# ---------
# Epoch 40/1000:
# Train Loss: 0.0897, Last LR: 0.0005
# Val Loss: 0.1022
# ---------
# Epoch 41/1000:
# Train Loss: 0.0896, Last LR: 0.0005
# Val Loss: 0.1024
# ---------
# Epoch 42/1000:
# Train Loss: 0.0895, Last LR: 0.0005
# Val Loss: 0.1023
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 43/1000:
# Train Loss: 0.0879, Last LR: 0.0003
# Val Loss: 0.1018
# ---------
# Epoch 44/1000:
# Train Loss: 0.0876, Last LR: 0.0003
# Val Loss: 0.1018
# ---------
# Epoch 45/1000:
# Train Loss: 0.0874, Last LR: 0.0003
# Val Loss: 0.1017
# ---------
# Epoch 46/1000:
# Train Loss: 0.0873, Last LR: 0.0003
# Val Loss: 0.1017
# ---------
# Epoch 47/1000:
# Train Loss: 0.0872, Last LR: 0.0003
# Val Loss: 0.1017
# ---------
# Epoch 48/1000:
# Train Loss: 0.0871, Last LR: 0.0003
# Val Loss: 0.1018
# ---------
# Epoch 49/1000:
# Train Loss: 0.0870, Last LR: 0.0003
# Val Loss: 0.1018
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 50/1000:
# Train Loss: 0.0862, Last LR: 0.0001
# Val Loss: 0.1010
# ---------
# Epoch 51/1000:
# Train Loss: 0.0860, Last LR: 0.0001
# Val Loss: 0.1010
# ---------
# Epoch 52/1000:
# Train Loss: 0.0859, Last LR: 0.0001
# Val Loss: 0.1010
# ---------
# Epoch 53/1000:
# Train Loss: 0.0858, Last LR: 0.0001
# Val Loss: 0.1011
# ---------
# Epoch 54/1000:
# Train Loss: 0.0857, Last LR: 0.0001
# Val Loss: 0.1011
# ---------
# Epoch 55/1000:
# Train Loss: 0.0857, Last LR: 0.0001
# Val Loss: 0.1011
# ---------
# Epoch 56/1000:
# Train Loss: 0.0856, Last LR: 0.0001
# Val Loss: 0.1011
# ---------
# Epoch 57/1000:
# Train Loss: 0.0855, Last LR: 0.0001
# Val Loss: 0.1011
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 58/1000:
# Train Loss: 0.0850, Last LR: 0.0001
# Val Loss: 0.1006
# ---------
# Epoch 59/1000:
# Train Loss: 0.0849, Last LR: 0.0001
# Val Loss: 0.1006
# ---------
# Epoch 60/1000:
# Train Loss: 0.0849, Last LR: 0.0001
# Val Loss: 0.1007
# ---------
# Epoch 61/1000:
# Train Loss: 0.0848, Last LR: 0.0001
# Val Loss: 0.1007
# ---------
# Epoch 62/1000:
# Train Loss: 0.0848, Last LR: 0.0001
# Val Loss: 0.1007
# ---------
# Epoch 63/1000:
# Train Loss: 0.0847, Last LR: 0.0001
# Val Loss: 0.1007
# ---------
# Epoch 64/1000:
# Train Loss: 0.0847, Last LR: 0.0001
# Val Loss: 0.1007
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 65/1000:
# Train Loss: 0.0845, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 66/1000:
# Train Loss: 0.0844, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 67/1000:
# Train Loss: 0.0844, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 68/1000:
# Train Loss: 0.0843, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 69/1000:
# Train Loss: 0.0843, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 70/1000:
# Train Loss: 0.0843, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 71/1000:
# Train Loss: 0.0843, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 72/1000:
# Train Loss: 0.0841, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 73/1000:
# Train Loss: 0.0841, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 74/1000:
# Train Loss: 0.0841, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 75/1000:
# Train Loss: 0.0841, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 76/1000:
# Train Loss: 0.0841, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 77/1000:
# Train Loss: 0.0841, Last LR: 0.0000
# Val Loss: 0.1006
# ---------
# Epoch 78/1000:
# Train Loss: 0.0840, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 79/1000:
# Train Loss: 0.0840, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 80/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 81/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 82/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 83/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 84/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 85/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 86/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 87/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 88/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 89/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 90/1000:
# Train Loss: 0.0839, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 91/1000:
# Train Loss: 0.0838, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 92/1000:
# Train Loss: 0.0838, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 93/1000:
# Train Loss: 0.0838, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 94/1000:
# Train Loss: 0.0838, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Epoch 95/1000:
# Train Loss: 0.0838, Last LR: 0.0000
# Val Loss: 0.1007
# ---------
# Early stopping ....
# 960.1403207778931 [s]

# %%
# trainer.load_model("./model_state2.pt")

# %%
trainer.plot_predictions(data_type='train')
# Out:
# RMSE for t2m: 2.2240288257598877; MAE for t2m: 1.7658109664916992;
# RMSE for tcc: 2.969144105911255; MAE for tcc: 2.3042850494384766;
# RMSE for u10: 0.22361648082733154; MAE for u10: 0.18092410266399384;
# RMSE for v10: 2.2224879264831543; MAE for v10: 1.5656461715698242;
# RMSE for tp: 1.442710280418396; MAE for tp: 1.1069217920303345;
# RMSE for sp: 0.00017247449432034045; MAE for sp: 7.69641701481305e-05;

# %%
trainer.plot_predictions(data_type='test')
# Out:
# RMSE for t2m: 1.7217416763305664; MAE for t2m: 1.3261842727661133;
# RMSE for tcc: 2.4002816677093506; MAE for tcc: 1.7858630418777466;
# RMSE for u10: 0.2240532785654068; MAE for u10: 0.1690119355916977;
# RMSE for v10: 1.4208723306655884; MAE for v10: 1.0826557874679565;
# RMSE for tp: 1.6283318996429443; MAE for tp: 1.1779483556747437;
# RMSE for sp: 0.0002213523257523775; MAE for sp: 0.00011144774180138484;
