# %%
import sys
sys.path.append('..')

from baselines.cnn.trainer import Trainer
# Out:
# c:\Users\iwama\Desktop\Maciej\Eng\meteoapp-data\venv\lib\site-packages\gribapi\__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.27.0
#   warnings.warn(

# %%
trainer = Trainer()

# %%
trainer.train(10)
# Out:
# Epoch 1/10:
# Train Loss: 0.0178, Last LR: 0.0010
# Val Loss: 0.0083
# ---------
# Epoch 2/10:
# Train Loss: 0.0076, Last LR: 0.0010
# Val Loss: 0.0085
# ---------
# Epoch 3/10:
# Train Loss: 0.0076, Last LR: 0.0010
# Val Loss: 0.0083
# ---------
# Epoch 4/10:
# Train Loss: 0.0076, Last LR: 0.0010
# Val Loss: 0.0084
# ---------
# Epoch 5/10:
# Train Loss: 0.0075, Last LR: 0.0010
# Val Loss: 0.0084
# ---------
# Epoch 6/10:
# Train Loss: 0.0075, Last LR: 0.0010
# Val Loss: 0.0084
# ---------
# Epoch 7/10:
# Train Loss: 0.0074, Last LR: 0.0010
# Val Loss: 0.0083
# ---------
# Epoch 8/10:
# Train Loss: 0.0073, Last LR: 0.0010
# Val Loss: 0.0083
# ---------
# Epoch 9/10:
# Train Loss: 0.0071, Last LR: 0.0010
# Val Loss: 0.0077
# ---------
# Epoch 10/10:
# Train Loss: 0.0066, Last LR: 0.0010
# Val Loss: 0.0067
# ---------
# 49.69774103164673 [s]

# %%
# trainer.load_model("./model_state2.pt")

# %%
trainer.plot_predictions(data_type='train')
# Out:
# RMSE for t2m: 14.323789450207205
# RMSE for tcc: 19.089658707794598
# RMSE for u10: 0.20022005067893742
# RMSE for v10: 3.094597440308823
# RMSE for tp: 3.305147900987171
# RMSE for sp: 0.0005524147930555025
