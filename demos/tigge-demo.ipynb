# %%
import sys

sys.path.append('..')

from baselines.tigge.tigge import load_tigge_0_to_12_by_6, evaluate_and_compare
from baselines.data_processor import DataProcessor

# %%
tigge = '../2022-01-01-to-2022-12-31.grib'
era = '../data2022_test.grib'

# %%
era_data =  DataProcessor.load_data(era)

# %%
a, tigge_data, b = load_tigge_0_to_12_by_6(tigge)

# %%
evaluate_and_compare(tigge_data, era_data)
# Out:
# <class 'numpy.ndarray'>
# t2m => RMSE:  1.00395; SE: 0.05657412225192445
# sp => RMSE:  3.25781; SE: 0.31931345090401136
# tcc => RMSE:  0.063; SE: 0.0012024836997770278
# u10 => RMSE:  0.62303; SE: 0.0425120454132074
# v10 => RMSE:  0.553; SE: 0.049648375363507184
# tp => RMSE:  0.00106; SE: 3.307303960752841e-06
# t2m => RMSE: 1.129
# sp => RMSE: 3.237
# tcc => RMSE: 0.252
# u10 => RMSE: 0.708
# v10 => RMSE: 0.696
# tp => RMSE: 0.001
