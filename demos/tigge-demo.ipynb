# %%
import sys

sys.path.append('..')

from models.tigge.tigge import load_tigge_0_to_12_by_6, evaluate_and_compare
from models.data_processor import DataProcessor

# %%
tigge = '../../2022-01-01-to-2022-12-31.grib'
# era = '../data/data2021-small.grib' # in config file

# %%
processor = DataProcessor()
era_data, _ = processor.data, processor.feature_list

# %%
a, tigge_data, b = load_tigge_0_to_12_by_6(tigge)

# %%
era_data.shape, tigge_data.shape
# Out:
# ((730, 25, 45, 6), (730, 25, 45, 6))

# %%
evaluate_and_compare(tigge_data, era_data)
# Out:
# t2m => RMSE:  0.9373034834861755; MAE: 0.8151018023490906; SE: 0.06886439504344807
# sp => RMSE:  3.23936128616333; MAE: 1.7286986112594604; SE: 0.5370595524648495
# tcc => RMSE:  0.033419039100408554; MAE: 0.007729905191808939; SE: 0.0012001758530835775
# u10 => RMSE:  0.5318956971168518; MAE: 0.3875238597393036; SE: 0.03561747644288368
# v10 => RMSE:  0.5776360034942627; MAE: 0.41472867131233215; SE: 0.02583659116559333
# tp => RMSE:  1.613515019416809; MAE: 0.9758032560348511; SE: 0.005460124612766916
# t2m => RMSE: 1.1279840469360352;  MAE: 0.8256531953811646;
# sp => RMSE: 3.236659288406372;  MAE: 1.7179852724075317;
# tcc => RMSE: 0.25114619731903076;  MAE: 0.1495499610900879;
# u10 => RMSE: 0.7078297734260559;  MAE: 0.5142908692359924;
# v10 => RMSE: 0.6960377097129822;  MAE: 0.5017737746238708;
# tp => RMSE: 1.399912714958191;  MAE: 0.4597792625427246;
