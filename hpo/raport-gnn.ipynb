# %%
import sys
sys.path.append("..")
from hpo import HPO

# %%
params = {
'baseline_type' : 'gnn',
'n_trials' : 1,
'dataset' : '../../data2022_full.grib',
'sequence_n_trials' : 5,
'fh_n_trials' : 5,
# 'engine' : 'greed'
}

# %%
hpo = HPO(**params)

# %%
hpo.run_and_report()
# Out:
# Epoch 1/3, Train Loss: 0.09605, lr: 0.001
# Val Loss: 0.09224
# ---------
# Epoch 2/3, Train Loss: 0.09449, lr: 0.001
# Val Loss: 0.09102
# ---------
# Epoch 3/3, Train Loss: 0.09307, lr: 0.001
# Val Loss: 0.08996
# ---------
# 2.896925926208496 [s]
# RMSE for t2m: 8.653638619234098; MAE for t2m: 7.351501982378981;
# RMSE for sp: 23.129192611213643; MAE for sp: 18.606585910373266;
# RMSE for tcc: 0.3313375059671899; MAE for tcc: 0.2878171878175696;
# RMSE for u10: 2.0962737231707593; MAE for u10: 1.6789309764938825;
# RMSE for v10: 2.804920385786356; MAE for v10: 2.2652868687744614;
# RMSE for tp: 0.26566356261546487; MAE for tp: 0.11474247977680829;
# Epoch 1/3, Train Loss: 0.09105, lr: 0.001
# Val Loss: 0.08878
# ---------
# Epoch 2/3, Train Loss: 0.09028, lr: 0.001
# Val Loss: 0.08821
# ---------
# Epoch 3/3, Train Loss: 0.08956, lr: 0.001
# Val Loss: 0.08767
# ---------
# 2.4985060691833496 [s]
# RMSE for t2m: 9.03598321471466; MAE for t2m: 8.635953694262446;
# ...

# %%
hpo.write_plots_to_json()
