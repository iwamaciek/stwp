# %%
import sys
sys.path.append("..")
from hpo import HPO

# %%
params = {
'baseline_type' : 'gnn',
'n_trials' : 10,
'dataset' : "../../data2019-2021_BIG.grib",
'sequence_n_trials' : 5,
'fh_n_trials' : 5,
'num_epochs' : 5,
}

# %%
hpo4 = HPO(**params)

# %%
hpo4.run_full_study()
# Out:
# Epoch 1/5, Train Loss: 0.16972, lr: 0.001
# Val Loss: 0.14457
# ---------
# Epoch 2/5, Train Loss: 0.14697, lr: 0.001
# Val Loss: 0.13225
# ---------
# Epoch 3/5, Train Loss: 0.13108, lr: 0.001
# Val Loss: 0.12155
# ---------
# Epoch 4/5, Train Loss: 0.11813, lr: 0.001
# Val Loss: 0.11095
# ---------
# Epoch 5/5, Train Loss: 0.10644, lr: 0.001
# Val Loss: 0.10029
# ---------
# 4.80422306060791 [s]
# Epoch 1/5, Train Loss: 0.28582, lr: 0.001
# Val Loss: 0.22877
# ---------
# Epoch 2/5, Train Loss: 0.23431, lr: 0.001
# Val Loss: 0.18644
# ---------
# Epoch 3/5, Train Loss: 0.19514, lr: 0.001
# Val Loss: 0.15514
# ---------
# Epoch 4/5, Train Loss: 0.16547, lr: 0.001
# Val Loss: 0.13379
# ---------
# Epoch 5/5, Train Loss: 0.14426, lr: 0.001
# Val Loss: 0.12006
# ---------
# 3.661052942276001 [s]
# Epoch 1/5, Train Loss: 0.18992, lr: 0.001
# Val Loss: 0.14312
# ---------
# Epoch 2/5, Train Loss: 0.15116, lr: 0.001
# Val Loss: 0.11701
# ---------
# ...

# %%
params = {
'baseline_type' : 'cnn',
'n_trials' : 5,
'dataset' : "../../data2019-2021_BIG.grib",
'sequence_n_trials' : 5,
'fh_n_trials' : 5,
'num_epochs' : 5,
}

# %%
hpo5 = HPO(**params)

# %%
hpo5.run_full_study()
# Out:
# Epoch 1/5, Train Loss: 0.09444, lr: 0.001
# Val Loss: 0.09176
# ---------
# Epoch 2/5, Train Loss: 0.09410, lr: 0.001
# Val Loss: 0.09138
# ---------
# Epoch 3/5, Train Loss: 0.09379, lr: 0.001
# Val Loss: 0.09097
# ---------
# Epoch 4/5, Train Loss: 0.09348, lr: 0.001
# Val Loss: 0.09070
# ---------
# Epoch 5/5, Train Loss: 0.09323, lr: 0.001
# Val Loss: 0.09047
# ---------
# 0.5455470085144043 [s]
# Epoch 1/5, Train Loss: 0.08990, lr: 0.001
# Val Loss: 0.09282
# ---------
# Epoch 2/5, Train Loss: 0.08956, lr: 0.001
# Val Loss: 0.09248
# ---------
# Epoch 3/5, Train Loss: 0.08919, lr: 0.001
# Val Loss: 0.09209
# ---------
# Epoch 4/5, Train Loss: 0.08878, lr: 0.001
# Val Loss: 0.09163
# ---------
# Epoch 5/5, Train Loss: 0.08829, lr: 0.001
# Val Loss: 0.09107
# ---------
# 0.4770357608795166 [s]
# Epoch 1/5, Train Loss: 0.08833, lr: 0.001
# Val Loss: 0.09197
# ---------
# Epoch 2/5, Train Loss: 0.08809, lr: 0.001
# Val Loss: 0.09161
# ---------
# ...
