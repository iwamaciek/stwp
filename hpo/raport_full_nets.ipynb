# %%
import sys
sys.path.append("..")
from hpo import HPO
# Out:
# /Users/piotrwojsznis/Library/Python/3.9/lib/python/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.30.0
#   warnings.warn(
# /Users/piotrwojsznis/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
params = {
'baseline_type' : 'gnn',
'n_trials' : 10,
'dataset' : "../../data2019-2021_BIG.grib",
'sequence_n_trials' : 10,
'fh_n_trials' : 10,
'num_epochs' : 100,
}

# %%
hpo4 = HPO(**params)

# %%
hpo4.run_full_study()
# Out:
# Epoch 1/100, Train Loss: 0.25258, lr: 0.001
# Val Loss: 0.21407
# ---------
# Epoch 2/100, Train Loss: 0.21291, lr: 0.001
# Val Loss: 0.17963
# ---------
# Epoch 3/100, Train Loss: 0.17983, lr: 0.001
# Val Loss: 0.15085
# ---------
# Epoch 4/100, Train Loss: 0.15315, lr: 0.001
# Val Loss: 0.12795
# ---------
# Epoch 5/100, Train Loss: 0.13188, lr: 0.001
# Val Loss: 0.11139
# ---------
# Epoch 6/100, Train Loss: 0.11679, lr: 0.001
# Val Loss: 0.10208
# ---------
# Epoch 7/100, Train Loss: 0.10807, lr: 0.001
# Val Loss: 0.09635
# ---------
# Epoch 8/100, Train Loss: 0.10213, lr: 0.001
# Val Loss: 0.09270
# ---------
# Epoch 9/100, Train Loss: 0.09766, lr: 0.001
# Val Loss: 0.09021
# ---------
# Epoch 10/100, Train Loss: 0.09411, lr: 0.001
# Val Loss: 0.08830
# ---------
# Epoch 11/100, Train Loss: 0.09115, lr: 0.001
# Val Loss: 0.08642
# ---------
# Epoch 12/100, Train Loss: 0.08870, lr: 0.001
# Val Loss: 0.08448
# ---------
# Epoch 13/100, Train Loss: 0.08655, lr: 0.001
# Val Loss: 0.08244
# ---------
# Epoch 14/100, Train Loss: 0.08464, lr: 0.001
# Val Loss: 0.08041
# ---------
# Epoch 15/100, Train Loss: 0.08277, lr: 0.001
# Val Loss: 0.07862
# ---------
# Epoch 16/100, Train Loss: 0.08077, lr: 0.001
# Val Loss: 0.07739
# ---------
# Epoch 17/100, Train Loss: 0.07877, lr: 0.001
# Val Loss: 0.07685
# ---------
# Epoch 18/100, Train Loss: 0.07704, lr: 0.001
# Val Loss: 0.07683
# ---------
# Epoch 19/100, Train Loss: 0.07579, lr: 0.001
# Val Loss: 0.07714
# ---------
# Epoch 20/100, Train Loss: 0.07504, lr: 0.001
# Val Loss: 0.07748
# ---------
# Epoch 21/100, Train Loss: 0.07458, lr: 0.001
# Val Loss: 0.07760
# ---------
# Epoch 22/100, Train Loss: 0.07413, lr: 0.001
# Val Loss: 0.07731
# ---------
# Epoch 23/100, Train Loss: 0.07342, lr: 0.001
# Val Loss: 0.07659
# ---------
# Epoch 24/100, Train Loss: 0.07241, lr: 0.001
# Val Loss: 0.07551
# ---------
# Epoch 25/100, Train Loss: 0.07121, lr: 0.001
# Val Loss: 0.07419
# ---------
# Epoch 26/100, Train Loss: 0.06997, lr: 0.001
# Val Loss: 0.07272
# ---------
# Epoch 27/100, Train Loss: 0.06878, lr: 0.001
# Val Loss: 0.07116
# ---------
# Epoch 28/100, Train Loss: 0.06759, lr: 0.001
# Val Loss: 0.06957
# ---------
# Epoch 29/100, Train Loss: 0.06640, lr: 0.001
# Val Loss: 0.06803
# ---------
# Epoch 30/100, Train Loss: 0.06529, lr: 0.001
# Val Loss: 0.06663
# ---------
# Epoch 31/100, Train Loss: 0.06434, lr: 0.001
# Val Loss: 0.06546
# ---------
# Epoch 32/100, Train Loss: 0.06359, lr: 0.001
# Val Loss: 0.06448
# ---------
# Epoch 33/100, Train Loss: 0.06299, lr: 0.001
# Val Loss: 0.06359
# ---------
# Epoch 34/100, Train Loss: 0.06242, lr: 0.001
# Val Loss: 0.06274
# ---------
# Epoch 35/100, Train Loss: 0.06178, lr: 0.001
# Val Loss: 0.06193
# ---------
# Epoch 36/100, Train Loss: 0.06107, lr: 0.001
# Val Loss: 0.06127
# ---------
# Epoch 37/100, Train Loss: 0.06036, lr: 0.001
# Val Loss: 0.06083
# ---------
# Epoch 38/100, Train Loss: 0.05969, lr: 0.001
# Val Loss: 0.06066
# ---------
# Epoch 39/100, Train Loss: 0.05911, lr: 0.001
# Val Loss: 0.06070
# ---------
# Epoch 40/100, Train Loss: 0.05857, lr: 0.001
# Val Loss: 0.06086
# ---------
# Epoch 41/100, Train Loss: 0.05802, lr: 0.001
# Val Loss: 0.06103
# ---------
# Epoch 42/100, Train Loss: 0.05745, lr: 0.001
# Val Loss: 0.06119
# ---------
# Epoch 43/100, Train Loss: 0.05688, lr: 0.001
# Val Loss: 0.06132
# ---------
# Epoch 44/100, Train Loss: 0.05632, lr: 0.001
# Val Loss: 0.06142
# ---------
# Epoch 45/100, Train Loss: 0.05575, lr: 0.001
# Val Loss: 0.06148
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 46/100, Train Loss: 0.05517, lr: 0.0005
# Val Loss: 0.06149
# ---------
# Epoch 47/100, Train Loss: 0.05487, lr: 0.0005
# Val Loss: 0.06148
# ---------
# Epoch 48/100, Train Loss: 0.05457, lr: 0.0005
# Val Loss: 0.06146
# ---------
# Epoch 49/100, Train Loss: 0.05428, lr: 0.0005
# Val Loss: 0.06144
# ---------
# Epoch 50/100, Train Loss: 0.05399, lr: 0.0005
# Val Loss: 0.06143
# ---------
# Epoch 51/100, Train Loss: 0.05370, lr: 0.0005
# Val Loss: 0.06141
# ---------
# Epoch 52/100, Train Loss: 0.05341, lr: 0.0005
# Val Loss: 0.06140
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 53/100, Train Loss: 0.05312, lr: 0.00025
# Val Loss: 0.06140
# ---------
# Epoch 54/100, Train Loss: 0.05298, lr: 0.00025
# Val Loss: 0.06141
# ---------
# Epoch 55/100, Train Loss: 0.05283, lr: 0.00025
# Val Loss: 0.06142
# ---------
# Epoch 56/100, Train Loss: 0.05269, lr: 0.00025
# Val Loss: 0.06143
# ---------
# Epoch 57/100, Train Loss: 0.05254, lr: 0.00025
# Val Loss: 0.06146
# ---------
# Epoch 58/100, Train Loss: 0.05240, lr: 0.00025
# Val Loss: 0.06148
# ---------
# Epoch 59/100, Train Loss: 0.05225, lr: 0.00025
# Val Loss: 0.06151
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 60/100, Train Loss: 0.05210, lr: 0.000125
# Val Loss: 0.06153
# ---------
# Epoch 61/100, Train Loss: 0.05203, lr: 0.000125
# Val Loss: 0.06155
# ---------
# Epoch 62/100, Train Loss: 0.05195, lr: 0.000125
# Val Loss: 0.06156
# ---------
# Epoch 63/100, Train Loss: 0.05187, lr: 0.000125
# Val Loss: 0.06158
# ---------
# Epoch 64/100, Train Loss: 0.05180, lr: 0.000125
# Val Loss: 0.06160
# ---------
# Epoch 65/100, Train Loss: 0.05172, lr: 0.000125
# Val Loss: 0.06162
# ---------
# Epoch 66/100, Train Loss: 0.05165, lr: 0.000125
# Val Loss: 0.06163
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 67/100, Train Loss: 0.05157, lr: 6.25e-05
# Val Loss: 0.06164
# ---------
# Epoch 68/100, Train Loss: 0.05153, lr: 6.25e-05
# Val Loss: 0.06165
# ---------
# Epoch 69/100, Train Loss: 0.05150, lr: 6.25e-05
# Val Loss: 0.06165
# ---------
# Epoch 70/100, Train Loss: 0.05146, lr: 6.25e-05
# Val Loss: 0.06166
# ---------
# Epoch 71/100, Train Loss: 0.05142, lr: 6.25e-05
# Val Loss: 0.06166
# ---------
# Epoch 72/100, Train Loss: 0.05138, lr: 6.25e-05
# Val Loss: 0.06167
# ---------
# Epoch 73/100, Train Loss: 0.05134, lr: 6.25e-05
# Val Loss: 0.06167
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 74/100, Train Loss: 0.05131, lr: 3.125e-05
# Val Loss: 0.06167
# ---------
# Epoch 75/100, Train Loss: 0.05129, lr: 3.125e-05
# Val Loss: 0.06167
# ---------
# Epoch 76/100, Train Loss: 0.05127, lr: 3.125e-05
# Val Loss: 0.06167
# ---------
# Epoch 77/100, Train Loss: 0.05125, lr: 3.125e-05
# Val Loss: 0.06167
# ---------
# Epoch 78/100, Train Loss: 0.05123, lr: 3.125e-05
# Val Loss: 0.06167
# ---------
# Early stopping ....
# 45.59643507003784 [s]
# Epoch 1/100, Train Loss: 0.18286, lr: 0.001
# Val Loss: 0.16124
# ---------
# Early stopping ....
# 0.5410332679748535 [s]
# Epoch 1/100, Train Loss: 0.21655, lr: 0.001
# Val Loss: 0.17734
# ---------
# Early stopping ....
# 0.5434308052062988 [s]
# Epoch 1/100, Train Loss: 0.21983, lr: 0.001
# Val Loss: 0.18987
# ---------
# Early stopping ....
# 0.5415840148925781 [s]
# Epoch 1/100, Train Loss: 0.30109, lr: 0.001
# Val Loss: 0.25959
# ---------
# Early stopping ....
# 0.5445430278778076 [s]
# Epoch 1/100, Train Loss: 0.17616, lr: 0.001
# Val Loss: 0.14616
# ---------
# Early stopping ....
# 0.5497100353240967 [s]
# Epoch 1/100, Train Loss: 0.12310, lr: 0.001
# Val Loss: 0.11918
# ---------
# Early stopping ....
# 0.5639100074768066 [s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 hpo4.run_full_study()
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/hpo.py:504, in HPO.run_full_study(self)
#     503 def run_full_study(self):
# --> 504     self.determine_best_s()
#     505     # self.best_s = 3
#     506     if self.baseline_type not in ['gnn', 'cnn']:
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/hpo.py:217, in HPO.determine_best_s(self)
#     215 cfg.FH  = self.fh
#     216 cfg.INPUT_SIZE = s
# --> 217 trainer.update_config(cfg)
#     218 trainer.train(num_epochs=self.num_epochs)
#     219 rmse_values, _ = trainer.evaluate("test", verbose=False)
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/gnn/trainer.py:75, in Trainer.update_config(self, c)
#      73 self.cfg = c
#      74 self.init_architecture()
# ---> 75 self.update_data_process()
#      76 self.init_train_details()
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/gnn/trainer.py:102, in Trainer.update_data_process(self)
#     100 def update_data_process(self):
#     101     self.nn_proc.update(self.cfg)
# --> 102     self.init_data_process()
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/gnn/trainer.py:79, in Trainer.init_data_process(self)
#      78 def init_data_process(self):
# ---> 79     self.nn_proc.preprocess(subset=self.subset)
#      80     self.train_loader = self.nn_proc.train_loader
#      81     self.val_loader = self.nn_proc.val_loader
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/gnn/processor.py:70, in NNDataProcessor.preprocess(self, subset)
#      68 X_train, X_test, y_train, y_test = self.train_val_test_split()
#      69 # print("Before scaling:", X_train[...,2].min(), X_train[...,2].max(), y_train[...,2].min(), y_train[...,2].min(), X_test[...,2].min(), X_test[...,2].min())
# ---> 70 X, y = self.fit_transform_scalers(
#      71     X_train, X_test, y_train, y_test, scaler_type=self.cfg.SCALER_TYPE
#      72 )
#      73 self.train_loader, self.val_loader, self.test_loader = self.get_loaders(
#      74     X, y, subset
#      75 )
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/gnn/processor.py:133, in NNDataProcessor.fit_transform_scalers(self, X_train, X_test, y_train, y_test, scaler_type)
#     126 self.scalers[i].fit(X_train_i)
#     127 X_train[..., i] = (
#     128     self.scalers[i]
#     129     .transform(X_train_i)
#     130     .reshape((self.train_size, Xi_shape))
#     131 )
#     132 X_test[..., i] = (
# --> 133     self.scalers[i]
#     134     .transform(X_test_i)
#     135     .reshape((self.test_size + self.val_size, Xi_shape))
#     136 )
#     137 y_train[..., i] = (
#     138     self.scalers[i]
#     139     .transform(y_train_i)
#     140     .reshape((self.train_size, yi_shape))
#     141 )
#     142 y_test[..., i] = (
#     143     self.scalers[i]
#     144     .transform(y_test_i)
#     145     .reshape((self.test_size + self.val_size, yi_shape))
#     146 )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/preprocessing/_data.py:1006, in StandardScaler.transform(self, X, copy)
#    1003 check_is_fitted(self)
#    1005 copy = copy if copy is not None else self.copy
# -> 1006 X = self._validate_data(
#    1007     X,
#    1008     reset=False,
#    1009     accept_sparse="csr",
#    1010     copy=copy,
#    1011     dtype=FLOAT_DTYPES,
#    1012     force_all_finite="allow-nan",
#    1013 )
#    1015 if sparse.issparse(X):
#    1016     if self.with_mean:
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/base.py:605, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     603         out = X, y
#     604 elif not no_val_X and no_val_y:
# --> 605     out = check_array(X, input_name="X", **check_params)
#     606 elif no_val_X and not no_val_y:
#     607     out = _check_y(y, **check_params)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:957, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     951         raise ValueError(
#     952             "Found array with dim %d. %s expected <= 2."
#     953             % (array.ndim, estimator_name)
#     954         )
#     956     if force_all_finite:
# --> 957         _assert_all_finite(
#     958             array,
#     959             input_name=input_name,
#     960             estimator_name=estimator_name,
#     961             allow_nan=force_all_finite == "allow-nan",
#     962         )
#     964 if ensure_min_samples > 0:
#     965     n_samples = _num_samples(array)
#
# File ~/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:118, in _assert_all_finite(X, allow_nan, msg_dtype, estimator_name, input_name)
#     113 # First try an O(n) time, O(1) space solution for the common case that
#     114 # everything is finite; fall back to O(n) space `np.isinf/isnan` or custom
#     115 # Cython implementation to prevent false positives and provide a detailed
#     116 # error message.
#     117 with np.errstate(over="ignore"):
# --> 118     first_pass_isfinite = xp.isfinite(xp.sum(X))
#     119 if first_pass_isfinite:
#     120     return
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/core/fromnumeric.py:2313, in sum(a, axis, dtype, out, keepdims, initial, where)
#    2310         return out
#    2311     return res
# -> 2313 return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
#    2314                       initial=initial, where=where)
#
# File ~/Library/Python/3.9/lib/python/site-packages/numpy/core/fromnumeric.py:88, in _wrapreduction(obj, ufunc, method, axis, dtype, out, **kwargs)
#      85         else:
#      86             return reduction(axis=axis, out=out, **passkwargs)
# ---> 88 return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
#
# KeyboardInterrupt:

# %%
params = {
'baseline_type' : 'cnn',
'n_trials' : 10,
'dataset' : "../../data2019-2021_BIG.grib",
'sequence_n_trials' : 10,
'fh_n_trials' : 10,
'num_epochs' : 100,
}

# %%
hpo5 = HPO(**params)

# %%
hpo5.run_full_study()
# Out:
# Epoch 1/100, Train Loss: 0.09344, lr: 0.001
# Val Loss: 0.09372
# ---------
# Epoch 2/100, Train Loss: 0.09296, lr: 0.001
# Val Loss: 0.09310
# ---------
# Epoch 3/100, Train Loss: 0.09249, lr: 0.001
# Val Loss: 0.09227
# ---------
# Epoch 4/100, Train Loss: 0.09188, lr: 0.001
# Val Loss: 0.09135
# ---------
# Epoch 5/100, Train Loss: 0.09122, lr: 0.001
# Val Loss: 0.09030
# ---------
# Epoch 6/100, Train Loss: 0.09050, lr: 0.001
# Val Loss: 0.08916
# ---------
# Epoch 7/100, Train Loss: 0.08968, lr: 0.001
# Val Loss: 0.08788
# ---------
# Epoch 8/100, Train Loss: 0.08886, lr: 0.001
# Val Loss: 0.08682
# ---------
# Epoch 9/100, Train Loss: 0.08854, lr: 0.001
# Val Loss: 0.08669
# ---------
# Epoch 10/100, Train Loss: 0.08888, lr: 0.001
# Val Loss: 0.08615
# ---------
# Epoch 11/100, Train Loss: 0.08816, lr: 0.001
# Val Loss: 0.08584
# ---------
# Epoch 12/100, Train Loss: 0.08761, lr: 0.001
# Val Loss: 0.08568
# ---------
# Epoch 13/100, Train Loss: 0.08734, lr: 0.001
# Val Loss: 0.08539
# ---------
# Epoch 14/100, Train Loss: 0.08708, lr: 0.001
# Val Loss: 0.08485
# ---------
# Epoch 15/100, Train Loss: 0.08671, lr: 0.001
# Val Loss: 0.08407
# ---------
# Epoch 16/100, Train Loss: 0.08624, lr: 0.001
# Val Loss: 0.08315
# ---------
# Epoch 17/100, Train Loss: 0.08573, lr: 0.001
# Val Loss: 0.08223
# ---------
# Epoch 18/100, Train Loss: 0.08525, lr: 0.001
# Val Loss: 0.08136
# ---------
# Epoch 19/100, Train Loss: 0.08478, lr: 0.001
# Val Loss: 0.08057
# ---------
# Epoch 20/100, Train Loss: 0.08426, lr: 0.001
# Val Loss: 0.07990
# ---------
# Epoch 21/100, Train Loss: 0.08368, lr: 0.001
# Val Loss: 0.07932
# ---------
# Epoch 22/100, Train Loss: 0.08312, lr: 0.001
# Val Loss: 0.07871
# ---------
# Epoch 23/100, Train Loss: 0.08254, lr: 0.001
# Val Loss: 0.07802
# ---------
# Epoch 24/100, Train Loss: 0.08189, lr: 0.001
# Val Loss: 0.07733
# ---------
# Epoch 25/100, Train Loss: 0.08121, lr: 0.001
# Val Loss: 0.07674
# ---------
# Epoch 26/100, Train Loss: 0.08054, lr: 0.001
# Val Loss: 0.07626
# ---------
# Epoch 27/100, Train Loss: 0.07987, lr: 0.001
# Val Loss: 0.07577
# ---------
# Epoch 28/100, Train Loss: 0.07922, lr: 0.001
# Val Loss: 0.07524
# ---------
# Epoch 29/100, Train Loss: 0.07859, lr: 0.001
# Val Loss: 0.07457
# ---------
# Epoch 30/100, Train Loss: 0.07789, lr: 0.001
# Val Loss: 0.07369
# ---------
# Epoch 31/100, Train Loss: 0.07717, lr: 0.001
# Val Loss: 0.07270
# ---------
# Epoch 32/100, Train Loss: 0.07650, lr: 0.001
# Val Loss: 0.07181
# ---------
# Epoch 33/100, Train Loss: 0.07580, lr: 0.001
# Val Loss: 0.07113
# ---------
# Epoch 34/100, Train Loss: 0.07500, lr: 0.001
# Val Loss: 0.07067
# ---------
# Epoch 35/100, Train Loss: 0.07411, lr: 0.001
# Val Loss: 0.07023
# ---------
# Epoch 36/100, Train Loss: 0.07314, lr: 0.001
# Val Loss: 0.06954
# ---------
# Epoch 37/100, Train Loss: 0.07200, lr: 0.001
# Val Loss: 0.06881
# ---------
# Epoch 38/100, Train Loss: 0.07078, lr: 0.001
# Val Loss: 0.06857
# ---------
# Epoch 39/100, Train Loss: 0.06975, lr: 0.001
# Val Loss: 0.06879
# ---------
# Epoch 40/100, Train Loss: 0.06902, lr: 0.001
# Val Loss: 0.06872
# ---------
# Epoch 41/100, Train Loss: 0.06842, lr: 0.001
# Val Loss: 0.06836
# ---------
# Epoch 42/100, Train Loss: 0.06790, lr: 0.001
# Val Loss: 0.06798
# ---------
# Epoch 43/100, Train Loss: 0.06750, lr: 0.001
# Val Loss: 0.06763
# ---------
# Epoch 44/100, Train Loss: 0.06723, lr: 0.001
# Val Loss: 0.06733
# ---------
# Epoch 45/100, Train Loss: 0.06691, lr: 0.001
# Val Loss: 0.06706
# ---------
# Epoch 46/100, Train Loss: 0.06641, lr: 0.001
# Val Loss: 0.06662
# ---------
# Epoch 47/100, Train Loss: 0.06578, lr: 0.001
# Val Loss: 0.06591
# ---------
# Epoch 48/100, Train Loss: 0.06504, lr: 0.001
# Val Loss: 0.06506
# ---------
# Epoch 49/100, Train Loss: 0.06437, lr: 0.001
# Val Loss: 0.06435
# ---------
# Epoch 50/100, Train Loss: 0.06373, lr: 0.001
# Val Loss: 0.06380
# ---------
# Epoch 51/100, Train Loss: 0.06316, lr: 0.001
# Val Loss: 0.06324
# ---------
# Epoch 52/100, Train Loss: 0.06272, lr: 0.001
# Val Loss: 0.06301
# ---------
# Epoch 53/100, Train Loss: 0.06240, lr: 0.001
# Val Loss: 0.06300
# ---------
# Epoch 54/100, Train Loss: 0.06202, lr: 0.001
# Val Loss: 0.06289
# ---------
# Epoch 55/100, Train Loss: 0.06158, lr: 0.001
# Val Loss: 0.06259
# ---------
# Epoch 56/100, Train Loss: 0.06109, lr: 0.001
# Val Loss: 0.06245
# ---------
# Epoch 57/100, Train Loss: 0.06058, lr: 0.001
# Val Loss: 0.06243
# ---------
# Epoch 58/100, Train Loss: 0.06013, lr: 0.001
# Val Loss: 0.06220
# ---------
# Epoch 59/100, Train Loss: 0.05974, lr: 0.001
# Val Loss: 0.06221
# ---------
# Epoch 60/100, Train Loss: 0.05935, lr: 0.001
# Val Loss: 0.06246
# ---------
# Epoch 61/100, Train Loss: 0.05896, lr: 0.001
# Val Loss: 0.06233
# ---------
# Epoch 62/100, Train Loss: 0.05852, lr: 0.001
# Val Loss: 0.06243
# ---------
# Epoch 63/100, Train Loss: 0.05807, lr: 0.001
# Val Loss: 0.06289
# ---------
# Epoch 64/100, Train Loss: 0.05793, lr: 0.001
# Val Loss: 0.06241
# ---------
# Epoch 65/100, Train Loss: 0.05778, lr: 0.001
# Val Loss: 0.06288
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 66/100, Train Loss: 0.05678, lr: 0.0005
# Val Loss: 0.06289
# ---------
# Epoch 67/100, Train Loss: 0.05645, lr: 0.0005
# Val Loss: 0.06267
# ---------
# Epoch 68/100, Train Loss: 0.05601, lr: 0.0005
# Val Loss: 0.06273
# ---------
# Epoch 69/100, Train Loss: 0.05576, lr: 0.0005
# Val Loss: 0.06292
# ---------
# Epoch 70/100, Train Loss: 0.05515, lr: 0.0005
# Val Loss: 0.06330
# ---------
# Epoch 71/100, Train Loss: 0.05486, lr: 0.0005
# Val Loss: 0.06322
# ---------
# Epoch 72/100, Train Loss: 0.05476, lr: 0.0005
# Val Loss: 0.06342
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 73/100, Train Loss: 0.05404, lr: 0.00025
# Val Loss: 0.06363
# ---------
# Epoch 74/100, Train Loss: 0.05391, lr: 0.00025
# Val Loss: 0.06363
# ---------
# Epoch 75/100, Train Loss: 0.05357, lr: 0.00025
# Val Loss: 0.06367
# ---------
# Epoch 76/100, Train Loss: 0.05339, lr: 0.00025
# Val Loss: 0.06383
# ---------
# Epoch 77/100, Train Loss: 0.05312, lr: 0.00025
# Val Loss: 0.06412
# ---------
# Epoch 78/100, Train Loss: 0.05291, lr: 0.00025
# Val Loss: 0.06426
# ---------
# Epoch 79/100, Train Loss: 0.05269, lr: 0.00025
# Val Loss: 0.06419
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 80/100, Train Loss: 0.05238, lr: 0.000125
# Val Loss: 0.06420
# ---------
# Epoch 81/100, Train Loss: 0.05228, lr: 0.000125
# Val Loss: 0.06430
# ---------
# Epoch 82/100, Train Loss: 0.05210, lr: 0.000125
# Val Loss: 0.06442
# ---------
# Epoch 83/100, Train Loss: 0.05196, lr: 0.000125
# Val Loss: 0.06444
# ---------
# Epoch 84/100, Train Loss: 0.05182, lr: 0.000125
# Val Loss: 0.06434
# ---------
# Epoch 85/100, Train Loss: 0.05165, lr: 0.000125
# Val Loss: 0.06414
# ---------
# Epoch 86/100, Train Loss: 0.05152, lr: 0.000125
# Val Loss: 0.06417
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 87/100, Train Loss: 0.05134, lr: 6.25e-05
# Val Loss: 0.06422
# ---------
# Epoch 88/100, Train Loss: 0.05126, lr: 6.25e-05
# Val Loss: 0.06428
# ---------
# Epoch 89/100, Train Loss: 0.05118, lr: 6.25e-05
# Val Loss: 0.06431
# ---------
# Epoch 90/100, Train Loss: 0.05110, lr: 6.25e-05
# Val Loss: 0.06431
# ---------
# Epoch 91/100, Train Loss: 0.05101, lr: 6.25e-05
# Val Loss: 0.06430
# ---------
# Epoch 92/100, Train Loss: 0.05092, lr: 6.25e-05
# Val Loss: 0.06433
# ---------
# Epoch 93/100, Train Loss: 0.05083, lr: 6.25e-05
# Val Loss: 0.06442
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 94/100, Train Loss: 0.05072, lr: 3.125e-05
# Val Loss: 0.06447
# ---------
# Epoch 95/100, Train Loss: 0.05067, lr: 3.125e-05
# Val Loss: 0.06451
# ---------
# Epoch 96/100, Train Loss: 0.05062, lr: 3.125e-05
# Val Loss: 0.06453
# ---------
# Epoch 97/100, Train Loss: 0.05057, lr: 3.125e-05
# Val Loss: 0.06452
# ---------
# Epoch 98/100, Train Loss: 0.05052, lr: 3.125e-05
# Val Loss: 0.06450
# ---------
# Early stopping ....
# 7.851289749145508 [s]
# Epoch 1/100, Train Loss: 0.09211, lr: 0.001
# Val Loss: 0.09185
# ---------
# Epoch 2/100, Train Loss: 0.09191, lr: 0.001
# Val Loss: 0.09153
# ---------
# Epoch 3/100, Train Loss: 0.09158, lr: 0.001
# Val Loss: 0.09115
# ---------
# Epoch 4/100, Train Loss: 0.09114, lr: 0.001
# Val Loss: 0.09066
# ---------
# Epoch 5/100, Train Loss: 0.09057, lr: 0.001
# Val Loss: 0.09002
# ---------
# Epoch 6/100, Train Loss: 0.08980, lr: 0.001
# Val Loss: 0.08918
# ---------
# Epoch 7/100, Train Loss: 0.08877, lr: 0.001
# Val Loss: 0.08815
# ---------
# Epoch 8/100, Train Loss: 0.08744, lr: 0.001
# Val Loss: 0.08752
# ---------
# Epoch 9/100, Train Loss: 0.08622, lr: 0.001
# Val Loss: 0.09039
# ---------
# Epoch 10/100, Train Loss: 0.08883, lr: 0.001
# Val Loss: 0.08828
# ---------
# Epoch 11/100, Train Loss: 0.08687, lr: 0.001
# Val Loss: 0.08688
# ---------
# Epoch 12/100, Train Loss: 0.08554, lr: 0.001
# Val Loss: 0.08678
# ---------
# Epoch 13/100, Train Loss: 0.08568, lr: 0.001
# Val Loss: 0.08678
# ---------
# Epoch 14/100, Train Loss: 0.08582, lr: 0.001
# Val Loss: 0.08668
# ---------
# Epoch 15/100, Train Loss: 0.08575, lr: 0.001
# Val Loss: 0.08645
# ---------
# Epoch 16/100, Train Loss: 0.08548, lr: 0.001
# Val Loss: 0.08609
# ---------
# Epoch 17/100, Train Loss: 0.08500, lr: 0.001
# Val Loss: 0.08566
# ---------
# Epoch 18/100, Train Loss: 0.08434, lr: 0.001
# Val Loss: 0.08524
# ---------
# Epoch 19/100, Train Loss: 0.08361, lr: 0.001
# Val Loss: 0.08508
# ---------
# Epoch 20/100, Train Loss: 0.08304, lr: 0.001
# Val Loss: 0.08529
# ---------
# Epoch 21/100, Train Loss: 0.08281, lr: 0.001
# Val Loss: 0.08555
# ---------
# Epoch 22/100, Train Loss: 0.08265, lr: 0.001
# Val Loss: 0.08535
# ---------
# Epoch 23/100, Train Loss: 0.08210, lr: 0.001
# Val Loss: 0.08479
# ---------
# Epoch 24/100, Train Loss: 0.08128, lr: 0.001
# Val Loss: 0.08431
# ---------
# Epoch 25/100, Train Loss: 0.08058, lr: 0.001
# Val Loss: 0.08405
# ---------
# Epoch 26/100, Train Loss: 0.08008, lr: 0.001
# Val Loss: 0.08395
# ---------
# Epoch 27/100, Train Loss: 0.07969, lr: 0.001
# Val Loss: 0.08389
# ---------
# Epoch 28/100, Train Loss: 0.07925, lr: 0.001
# Val Loss: 0.08373
# ---------
# Epoch 29/100, Train Loss: 0.07873, lr: 0.001
# Val Loss: 0.08337
# ---------
# Epoch 30/100, Train Loss: 0.07820, lr: 0.001
# Val Loss: 0.08276
# ---------
# Epoch 31/100, Train Loss: 0.07766, lr: 0.001
# Val Loss: 0.08195
# ---------
# Epoch 32/100, Train Loss: 0.07715, lr: 0.001
# Val Loss: 0.08098
# ---------
# Epoch 33/100, Train Loss: 0.07657, lr: 0.001
# Val Loss: 0.07998
# ---------
# Epoch 34/100, Train Loss: 0.07586, lr: 0.001
# Val Loss: 0.07911
# ---------
# Epoch 35/100, Train Loss: 0.07523, lr: 0.001
# Val Loss: 0.07834
# ---------
# Epoch 36/100, Train Loss: 0.07464, lr: 0.001
# Val Loss: 0.07750
# ---------
# Epoch 37/100, Train Loss: 0.07395, lr: 0.001
# Val Loss: 0.07650
# ---------
# Epoch 38/100, Train Loss: 0.07322, lr: 0.001
# Val Loss: 0.07527
# ---------
# Epoch 39/100, Train Loss: 0.07249, lr: 0.001
# Val Loss: 0.07385
# ---------
# Epoch 40/100, Train Loss: 0.07176, lr: 0.001
# Val Loss: 0.07251
# ---------
# Epoch 41/100, Train Loss: 0.07102, lr: 0.001
# Val Loss: 0.07152
# ---------
# Epoch 42/100, Train Loss: 0.07023, lr: 0.001
# Val Loss: 0.07064
# ---------
# Epoch 43/100, Train Loss: 0.06931, lr: 0.001
# Val Loss: 0.06984
# ---------
# Epoch 44/100, Train Loss: 0.06857, lr: 0.001
# Val Loss: 0.06902
# ---------
# Epoch 45/100, Train Loss: 0.06794, lr: 0.001
# Val Loss: 0.06811
# ---------
# Epoch 46/100, Train Loss: 0.06729, lr: 0.001
# Val Loss: 0.06755
# ---------
# Epoch 47/100, Train Loss: 0.06678, lr: 0.001
# Val Loss: 0.06697
# ---------
# Epoch 48/100, Train Loss: 0.06619, lr: 0.001
# Val Loss: 0.06646
# ---------
# Epoch 49/100, Train Loss: 0.06562, lr: 0.001
# Val Loss: 0.06591
# ---------
# Epoch 50/100, Train Loss: 0.06506, lr: 0.001
# Val Loss: 0.06514
# ---------
# Epoch 51/100, Train Loss: 0.06437, lr: 0.001
# Val Loss: 0.06451
# ---------
# Epoch 52/100, Train Loss: 0.06376, lr: 0.001
# Val Loss: 0.06408
# ---------
# Epoch 53/100, Train Loss: 0.06303, lr: 0.001
# Val Loss: 0.06362
# ---------
# Epoch 54/100, Train Loss: 0.06225, lr: 0.001
# Val Loss: 0.06312
# ---------
# Epoch 55/100, Train Loss: 0.06158, lr: 0.001
# Val Loss: 0.06300
# ---------
# Epoch 56/100, Train Loss: 0.06094, lr: 0.001
# Val Loss: 0.06297
# ---------
# Epoch 57/100, Train Loss: 0.06034, lr: 0.001
# Val Loss: 0.06252
# ---------
# Epoch 58/100, Train Loss: 0.05961, lr: 0.001
# Val Loss: 0.06242
# ---------
# Epoch 59/100, Train Loss: 0.05889, lr: 0.001
# Val Loss: 0.06241
# ---------
# Epoch 60/100, Train Loss: 0.05817, lr: 0.001
# Val Loss: 0.06164
# ---------
# Epoch 61/100, Train Loss: 0.05760, lr: 0.001
# Val Loss: 0.06220
# ---------
# Epoch 62/100, Train Loss: 0.05690, lr: 0.001
# Val Loss: 0.06163
# ---------
# Epoch 63/100, Train Loss: 0.05611, lr: 0.001
# Val Loss: 0.06175
# ---------
# Epoch 64/100, Train Loss: 0.05552, lr: 0.001
# Val Loss: 0.06263
# ---------
# Epoch 65/100, Train Loss: 0.05521, lr: 0.001
# Val Loss: 0.06149
# ---------
# Epoch 66/100, Train Loss: 0.05484, lr: 0.001
# Val Loss: 0.06149
# ---------
# Epoch 67/100, Train Loss: 0.05369, lr: 0.001
# Val Loss: 0.06116
# ---------
# Epoch 68/100, Train Loss: 0.05311, lr: 0.001
# Val Loss: 0.06038
# ---------
# Epoch 69/100, Train Loss: 0.05275, lr: 0.001
# Val Loss: 0.06098
# ---------
# Epoch 70/100, Train Loss: 0.05210, lr: 0.001
# Val Loss: 0.06060
# ---------
# Epoch 71/100, Train Loss: 0.05141, lr: 0.001
# Val Loss: 0.06042
# ---------
# Epoch 72/100, Train Loss: 0.05146, lr: 0.001
# Val Loss: 0.06157
# ---------
# Epoch 73/100, Train Loss: 0.05142, lr: 0.001
# Val Loss: 0.06064
# ---------
# Epoch 74/100, Train Loss: 0.05049, lr: 0.001
# Val Loss: 0.06078
# ---------
# Epoch 75/100, Train Loss: 0.05100, lr: 0.001
# Val Loss: 0.06065
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 76/100, Train Loss: 0.05001, lr: 0.0005
# Val Loss: 0.06050
# ---------
# Epoch 77/100, Train Loss: 0.04972, lr: 0.0005
# Val Loss: 0.06005
# ---------
# Epoch 78/100, Train Loss: 0.04948, lr: 0.0005
# Val Loss: 0.05984
# ---------
# Epoch 79/100, Train Loss: 0.04947, lr: 0.0005
# Val Loss: 0.05979
# ---------
# Epoch 80/100, Train Loss: 0.04902, lr: 0.0005
# Val Loss: 0.06008
# ---------
# Epoch 81/100, Train Loss: 0.04903, lr: 0.0005
# Val Loss: 0.06004
# ---------
# Epoch 82/100, Train Loss: 0.04891, lr: 0.0005
# Val Loss: 0.05969
# ---------
# Epoch 83/100, Train Loss: 0.04862, lr: 0.0005
# Val Loss: 0.05957
# ---------
# Epoch 84/100, Train Loss: 0.04853, lr: 0.0005
# Val Loss: 0.05963
# ---------
# Epoch 85/100, Train Loss: 0.04839, lr: 0.0005
# Val Loss: 0.05964
# ---------
# Epoch 86/100, Train Loss: 0.04809, lr: 0.0005
# Val Loss: 0.05975
# ---------
# Epoch 87/100, Train Loss: 0.04811, lr: 0.0005
# Val Loss: 0.05969
# ---------
# Epoch 88/100, Train Loss: 0.04792, lr: 0.0005
# Val Loss: 0.05959
# ---------
# Epoch 89/100, Train Loss: 0.04769, lr: 0.0005
# Val Loss: 0.05956
# ---------
# Epoch 90/100, Train Loss: 0.04764, lr: 0.0005
# Val Loss: 0.05954
# ---------
# Epoch 91/100, Train Loss: 0.04739, lr: 0.0005
# Val Loss: 0.05970
# ---------
# Epoch 92/100, Train Loss: 0.04726, lr: 0.0005
# Val Loss: 0.05985
# ---------
# Epoch 93/100, Train Loss: 0.04719, lr: 0.0005
# Val Loss: 0.05971
# ---------
# Epoch 94/100, Train Loss: 0.04695, lr: 0.0005
# Val Loss: 0.05960
# ---------
# Epoch 95/100, Train Loss: 0.04689, lr: 0.0005
# Val Loss: 0.05966
# ---------
# Epoch 96/100, Train Loss: 0.04669, lr: 0.0005
# Val Loss: 0.05984
# ---------
# Epoch 97/100, Train Loss: 0.04654, lr: 0.0005
# Val Loss: 0.05995
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 98/100, Train Loss: 0.04645, lr: 0.00025
# Val Loss: 0.05990
# ---------
# Epoch 99/100, Train Loss: 0.04633, lr: 0.00025
# Val Loss: 0.05981
# ---------
# Epoch 100/100, Train Loss: 0.04624, lr: 0.00025
# Val Loss: 0.05977
# ---------
# 8.831146240234375 [s]
# Epoch 1/100, Train Loss: 0.09006, lr: 0.001
# Val Loss: 0.09198
# ---------
# Epoch 2/100, Train Loss: 0.08961, lr: 0.001
# Val Loss: 0.09168
# ---------
# Epoch 3/100, Train Loss: 0.08927, lr: 0.001
# Val Loss: 0.09137
# ---------
# Epoch 4/100, Train Loss: 0.08889, lr: 0.001
# Val Loss: 0.09103
# ---------
# Epoch 5/100, Train Loss: 0.08848, lr: 0.001
# Val Loss: 0.09069
# ---------
# Epoch 6/100, Train Loss: 0.08800, lr: 0.001
# Val Loss: 0.09058
# ---------
# Epoch 7/100, Train Loss: 0.08771, lr: 0.001
# Val Loss: 0.09048
# ---------
# Epoch 8/100, Train Loss: 0.08743, lr: 0.001
# Val Loss: 0.09010
# ---------
# Epoch 9/100, Train Loss: 0.08690, lr: 0.001
# Val Loss: 0.08969
# ---------
# Epoch 10/100, Train Loss: 0.08633, lr: 0.001
# Val Loss: 0.08941
# ---------
# Epoch 11/100, Train Loss: 0.08591, lr: 0.001
# Val Loss: 0.08907
# ---------
# Epoch 12/100, Train Loss: 0.08547, lr: 0.001
# Val Loss: 0.08851
# ---------
# Epoch 13/100, Train Loss: 0.08505, lr: 0.001
# Val Loss: 0.08781
# ---------
# Epoch 14/100, Train Loss: 0.08487, lr: 0.001
# Val Loss: 0.08745
# ---------
# Epoch 15/100, Train Loss: 0.08422, lr: 0.001
# Val Loss: 0.08704
# ---------
# Epoch 16/100, Train Loss: 0.08376, lr: 0.001
# Val Loss: 0.08640
# ---------
# Epoch 17/100, Train Loss: 0.08329, lr: 0.001
# Val Loss: 0.08561
# ---------
# Epoch 18/100, Train Loss: 0.08281, lr: 0.001
# Val Loss: 0.08476
# ---------
# Epoch 19/100, Train Loss: 0.08241, lr: 0.001
# Val Loss: 0.08379
# ---------
# Epoch 20/100, Train Loss: 0.08190, lr: 0.001
# Val Loss: 0.08278
# ---------
# Epoch 21/100, Train Loss: 0.08134, lr: 0.001
# Val Loss: 0.08190
# ---------
# Epoch 22/100, Train Loss: 0.08090, lr: 0.001
# Val Loss: 0.08124
# ---------
# Epoch 23/100, Train Loss: 0.08048, lr: 0.001
# Val Loss: 0.08096
# ---------
# Epoch 24/100, Train Loss: 0.07996, lr: 0.001
# Val Loss: 0.08085
# ---------
# Epoch 25/100, Train Loss: 0.07939, lr: 0.001
# Val Loss: 0.08060
# ---------
# Epoch 26/100, Train Loss: 0.07868, lr: 0.001
# Val Loss: 0.08043
# ---------
# Epoch 27/100, Train Loss: 0.07786, lr: 0.001
# Val Loss: 0.08077
# ---------
# Epoch 28/100, Train Loss: 0.07697, lr: 0.001
# Val Loss: 0.08114
# ---------
# Epoch 29/100, Train Loss: 0.07639, lr: 0.001
# Val Loss: 0.08105
# ---------
# Epoch 30/100, Train Loss: 0.07613, lr: 0.001
# Val Loss: 0.08058
# ---------
# Epoch 31/100, Train Loss: 0.07523, lr: 0.001
# Val Loss: 0.08000
# ---------
# Epoch 32/100, Train Loss: 0.07448, lr: 0.001
# Val Loss: 0.07950
# ---------
# Epoch 33/100, Train Loss: 0.07394, lr: 0.001
# Val Loss: 0.07896
# ---------
# Epoch 34/100, Train Loss: 0.07335, lr: 0.001
# Val Loss: 0.07858
# ---------
# Epoch 35/100, Train Loss: 0.07283, lr: 0.001
# Val Loss: 0.07855
# ---------
# Epoch 36/100, Train Loss: 0.07224, lr: 0.001
# Val Loss: 0.07860
# ---------
# Epoch 37/100, Train Loss: 0.07171, lr: 0.001
# Val Loss: 0.07835
# ---------
# Epoch 38/100, Train Loss: 0.07108, lr: 0.001
# Val Loss: 0.07813
# ---------
# Epoch 39/100, Train Loss: 0.07056, lr: 0.001
# Val Loss: 0.07807
# ---------
# Epoch 40/100, Train Loss: 0.07010, lr: 0.001
# Val Loss: 0.07799
# ---------
# Epoch 41/100, Train Loss: 0.06971, lr: 0.001
# Val Loss: 0.07786
# ---------
# Epoch 42/100, Train Loss: 0.06921, lr: 0.001
# Val Loss: 0.07783
# ---------
# Epoch 43/100, Train Loss: 0.06869, lr: 0.001
# Val Loss: 0.07771
# ---------
# Epoch 44/100, Train Loss: 0.06816, lr: 0.001
# Val Loss: 0.07739
# ---------
# Epoch 45/100, Train Loss: 0.06765, lr: 0.001
# Val Loss: 0.07704
# ---------
# Epoch 46/100, Train Loss: 0.06720, lr: 0.001
# Val Loss: 0.07663
# ---------
# Epoch 47/100, Train Loss: 0.06665, lr: 0.001
# Val Loss: 0.07639
# ---------
# Epoch 48/100, Train Loss: 0.06601, lr: 0.001
# Val Loss: 0.07700
# ---------
# Epoch 49/100, Train Loss: 0.06536, lr: 0.001
# Val Loss: 0.07753
# ---------
# Epoch 50/100, Train Loss: 0.06479, lr: 0.001
# Val Loss: 0.07716
# ---------
# Epoch 51/100, Train Loss: 0.06413, lr: 0.001
# Val Loss: 0.07801
# ---------
# Epoch 52/100, Train Loss: 0.06383, lr: 0.001
# Val Loss: 0.07513
# ---------
# Epoch 53/100, Train Loss: 0.06416, lr: 0.001
# Val Loss: 0.07451
# ---------
# Epoch 54/100, Train Loss: 0.06342, lr: 0.001
# Val Loss: 0.07707
# ---------
# Epoch 55/100, Train Loss: 0.06258, lr: 0.001
# Val Loss: 0.07622
# ---------
# Epoch 56/100, Train Loss: 0.06174, lr: 0.001
# Val Loss: 0.07529
# ---------
# Epoch 57/100, Train Loss: 0.06173, lr: 0.001
# Val Loss: 0.07580
# ---------
# Epoch 58/100, Train Loss: 0.06101, lr: 0.001
# Val Loss: 0.07749
# ---------
# Epoch 59/100, Train Loss: 0.06097, lr: 0.001
# Val Loss: 0.07441
# ---------
# Epoch 60/100, Train Loss: 0.06050, lr: 0.001
# Val Loss: 0.07404
# ---------
# Epoch 61/100, Train Loss: 0.06034, lr: 0.001
# Val Loss: 0.07467
# ---------
# Epoch 62/100, Train Loss: 0.05936, lr: 0.001
# Val Loss: 0.07705
# ---------
# Epoch 63/100, Train Loss: 0.05985, lr: 0.001
# Val Loss: 0.07479
# ---------
# Epoch 64/100, Train Loss: 0.05861, lr: 0.001
# Val Loss: 0.07394
# ---------
# Epoch 65/100, Train Loss: 0.05856, lr: 0.001
# Val Loss: 0.07388
# ---------
# Epoch 66/100, Train Loss: 0.05800, lr: 0.001
# Val Loss: 0.07521
# ---------
# Epoch 67/100, Train Loss: 0.05775, lr: 0.001
# Val Loss: 0.07507
# ---------
# Epoch 68/100, Train Loss: 0.05714, lr: 0.001
# Val Loss: 0.07472
# ---------
# Epoch 69/100, Train Loss: 0.05702, lr: 0.001
# Val Loss: 0.07457
# ---------
# Epoch 70/100, Train Loss: 0.05645, lr: 0.001
# Val Loss: 0.07477
# ---------
# Epoch 71/100, Train Loss: 0.05629, lr: 0.001
# Val Loss: 0.07418
# ---------
# Epoch 72/100, Train Loss: 0.05580, lr: 0.001
# Val Loss: 0.07461
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 73/100, Train Loss: 0.05552, lr: 0.0005
# Val Loss: 0.07486
# ---------
# Epoch 74/100, Train Loss: 0.05526, lr: 0.0005
# Val Loss: 0.07503
# ---------
# Epoch 75/100, Train Loss: 0.05513, lr: 0.0005
# Val Loss: 0.07493
# ---------
# Epoch 76/100, Train Loss: 0.05497, lr: 0.0005
# Val Loss: 0.07463
# ---------
# Epoch 77/100, Train Loss: 0.05473, lr: 0.0005
# Val Loss: 0.07453
# ---------
# Epoch 78/100, Train Loss: 0.05464, lr: 0.0005
# Val Loss: 0.07469
# ---------
# Epoch 79/100, Train Loss: 0.05442, lr: 0.0005
# Val Loss: 0.07496
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 80/100, Train Loss: 0.05422, lr: 0.00025
# Val Loss: 0.07501
# ---------
# Epoch 81/100, Train Loss: 0.05416, lr: 0.00025
# Val Loss: 0.07492
# ---------
# Epoch 82/100, Train Loss: 0.05406, lr: 0.00025
# Val Loss: 0.07476
# ---------
# Epoch 83/100, Train Loss: 0.05395, lr: 0.00025
# Val Loss: 0.07462
# ---------
# Epoch 84/100, Train Loss: 0.05389, lr: 0.00025
# Val Loss: 0.07458
# ---------
# Epoch 85/100, Train Loss: 0.05381, lr: 0.00025
# Val Loss: 0.07463
# ---------
# Epoch 86/100, Train Loss: 0.05370, lr: 0.00025
# Val Loss: 0.07477
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 87/100, Train Loss: 0.05361, lr: 0.000125
# Val Loss: 0.07484
# ---------
# Epoch 88/100, Train Loss: 0.05357, lr: 0.000125
# Val Loss: 0.07488
# ---------
# Epoch 89/100, Train Loss: 0.05353, lr: 0.000125
# Val Loss: 0.07491
# ---------
# Epoch 90/100, Train Loss: 0.05348, lr: 0.000125
# Val Loss: 0.07491
# ---------
# Epoch 91/100, Train Loss: 0.05343, lr: 0.000125
# Val Loss: 0.07491
# ---------
# Epoch 92/100, Train Loss: 0.05339, lr: 0.000125
# Val Loss: 0.07490
# ---------
# Epoch 93/100, Train Loss: 0.05335, lr: 0.000125
# Val Loss: 0.07490
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 94/100, Train Loss: 0.05330, lr: 6.25e-05
# Val Loss: 0.07490
# ---------
# Epoch 95/100, Train Loss: 0.05328, lr: 6.25e-05
# Val Loss: 0.07490
# ---------
# Epoch 96/100, Train Loss: 0.05325, lr: 6.25e-05
# Val Loss: 0.07490
# ---------
# Epoch 97/100, Train Loss: 0.05323, lr: 6.25e-05
# Val Loss: 0.07489
# ---------
# Epoch 98/100, Train Loss: 0.05321, lr: 6.25e-05
# Val Loss: 0.07488
# ---------
# Epoch 99/100, Train Loss: 0.05319, lr: 6.25e-05
# Val Loss: 0.07487
# ---------
# Epoch 100/100, Train Loss: 0.05317, lr: 6.25e-05
# Val Loss: 0.07485
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# 8.620049953460693 [s]
# Epoch 1/100, Train Loss: 0.09148, lr: 0.001
# Val Loss: 0.09641
# ---------
# Epoch 2/100, Train Loss: 0.09128, lr: 0.001
# Val Loss: 0.09633
# ---------
# Epoch 3/100, Train Loss: 0.09116, lr: 0.001
# Val Loss: 0.09625
# ---------
# Epoch 4/100, Train Loss: 0.09108, lr: 0.001
# Val Loss: 0.09612
# ---------
# Epoch 5/100, Train Loss: 0.09099, lr: 0.001
# Val Loss: 0.09596
# ---------
# Epoch 6/100, Train Loss: 0.09089, lr: 0.001
# Val Loss: 0.09576
# ---------
# Epoch 7/100, Train Loss: 0.09076, lr: 0.001
# Val Loss: 0.09551
# ---------
# Epoch 8/100, Train Loss: 0.09059, lr: 0.001
# Val Loss: 0.09517
# ---------
# Epoch 9/100, Train Loss: 0.09038, lr: 0.001
# Val Loss: 0.09466
# ---------
# Epoch 10/100, Train Loss: 0.09007, lr: 0.001
# Val Loss: 0.09376
# ---------
# Epoch 11/100, Train Loss: 0.08959, lr: 0.001
# Val Loss: 0.09171
# ---------
# Epoch 12/100, Train Loss: 0.08875, lr: 0.001
# Val Loss: 0.08741
# ---------
# Epoch 13/100, Train Loss: 0.08915, lr: 0.001
# Val Loss: 0.08902
# ---------
# Epoch 14/100, Train Loss: 0.08751, lr: 0.001
# Val Loss: 0.08978
# ---------
# Epoch 15/100, Train Loss: 0.08739, lr: 0.001
# Val Loss: 0.08953
# ---------
# Epoch 16/100, Train Loss: 0.08700, lr: 0.001
# Val Loss: 0.08847
# ---------
# Epoch 17/100, Train Loss: 0.08624, lr: 0.001
# Val Loss: 0.08644
# ---------
# Epoch 18/100, Train Loss: 0.08498, lr: 0.001
# Val Loss: 0.08349
# ---------
# Epoch 19/100, Train Loss: 0.08319, lr: 0.001
# Val Loss: 0.08407
# ---------
# Epoch 20/100, Train Loss: 0.08415, lr: 0.001
# Val Loss: 0.08283
# ---------
# Epoch 21/100, Train Loss: 0.08190, lr: 0.001
# Val Loss: 0.08306
# ---------
# Epoch 22/100, Train Loss: 0.08125, lr: 0.001
# Val Loss: 0.08360
# ---------
# Epoch 23/100, Train Loss: 0.08106, lr: 0.001
# Val Loss: 0.08336
# ---------
# Epoch 24/100, Train Loss: 0.08034, lr: 0.001
# Val Loss: 0.08244
# ---------
# Epoch 25/100, Train Loss: 0.07899, lr: 0.001
# Val Loss: 0.08185
# ---------
# Epoch 26/100, Train Loss: 0.07795, lr: 0.001
# Val Loss: 0.08198
# ---------
# Epoch 27/100, Train Loss: 0.07800, lr: 0.001
# Val Loss: 0.08090
# ---------
# Epoch 28/100, Train Loss: 0.07634, lr: 0.001
# Val Loss: 0.08064
# ---------
# Epoch 29/100, Train Loss: 0.07581, lr: 0.001
# Val Loss: 0.08056
# ---------
# Epoch 30/100, Train Loss: 0.07539, lr: 0.001
# Val Loss: 0.08034
# ---------
# Epoch 31/100, Train Loss: 0.07469, lr: 0.001
# Val Loss: 0.08031
# ---------
# Epoch 32/100, Train Loss: 0.07396, lr: 0.001
# Val Loss: 0.08075
# ---------
# Epoch 33/100, Train Loss: 0.07340, lr: 0.001
# Val Loss: 0.08125
# ---------
# Epoch 34/100, Train Loss: 0.07285, lr: 0.001
# Val Loss: 0.08130
# ---------
# Epoch 35/100, Train Loss: 0.07204, lr: 0.001
# Val Loss: 0.08157
# ---------
# Epoch 36/100, Train Loss: 0.07137, lr: 0.001
# Val Loss: 0.08233
# ---------
# Epoch 37/100, Train Loss: 0.07092, lr: 0.001
# Val Loss: 0.08306
# ---------
# Epoch 38/100, Train Loss: 0.07064, lr: 0.001
# Val Loss: 0.08341
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 39/100, Train Loss: 0.07040, lr: 0.0005
# Val Loss: 0.08334
# ---------
# Epoch 40/100, Train Loss: 0.07004, lr: 0.0005
# Val Loss: 0.08308
# ---------
# Epoch 41/100, Train Loss: 0.06956, lr: 0.0005
# Val Loss: 0.08270
# ---------
# Epoch 42/100, Train Loss: 0.06913, lr: 0.0005
# Val Loss: 0.08231
# ---------
# Epoch 43/100, Train Loss: 0.06873, lr: 0.0005
# Val Loss: 0.08205
# ---------
# Epoch 44/100, Train Loss: 0.06837, lr: 0.0005
# Val Loss: 0.08196
# ---------
# Epoch 45/100, Train Loss: 0.06815, lr: 0.0005
# Val Loss: 0.08177
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 46/100, Train Loss: 0.06780, lr: 0.00025
# Val Loss: 0.08166
# ---------
# Epoch 47/100, Train Loss: 0.06758, lr: 0.00025
# Val Loss: 0.08159
# ---------
# Epoch 48/100, Train Loss: 0.06738, lr: 0.00025
# Val Loss: 0.08158
# ---------
# Epoch 49/100, Train Loss: 0.06715, lr: 0.00025
# Val Loss: 0.08161
# ---------
# Epoch 50/100, Train Loss: 0.06689, lr: 0.00025
# Val Loss: 0.08166
# ---------
# Epoch 51/100, Train Loss: 0.06667, lr: 0.00025
# Val Loss: 0.08170
# ---------
# Epoch 52/100, Train Loss: 0.06649, lr: 0.00025
# Val Loss: 0.08172
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 53/100, Train Loss: 0.06630, lr: 0.000125
# Val Loss: 0.08172
# ---------
# Epoch 54/100, Train Loss: 0.06620, lr: 0.000125
# Val Loss: 0.08171
# ---------
# Epoch 55/100, Train Loss: 0.06612, lr: 0.000125
# Val Loss: 0.08169
# ---------
# Epoch 56/100, Train Loss: 0.06604, lr: 0.000125
# Val Loss: 0.08164
# ---------
# Epoch 57/100, Train Loss: 0.06594, lr: 0.000125
# Val Loss: 0.08159
# ---------
# Epoch 58/100, Train Loss: 0.06584, lr: 0.000125
# Val Loss: 0.08152
# ---------
# Epoch 59/100, Train Loss: 0.06576, lr: 0.000125
# Val Loss: 0.08144
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 60/100, Train Loss: 0.06568, lr: 6.25e-05
# Val Loss: 0.08140
# ---------
# Epoch 61/100, Train Loss: 0.06564, lr: 6.25e-05
# Val Loss: 0.08135
# ---------
# Epoch 62/100, Train Loss: 0.06559, lr: 6.25e-05
# Val Loss: 0.08130
# ---------
# Epoch 63/100, Train Loss: 0.06555, lr: 6.25e-05
# Val Loss: 0.08124
# ---------
# Epoch 64/100, Train Loss: 0.06550, lr: 6.25e-05
# Val Loss: 0.08119
# ---------
# Epoch 65/100, Train Loss: 0.06546, lr: 6.25e-05
# Val Loss: 0.08114
# ---------
# Epoch 66/100, Train Loss: 0.06542, lr: 6.25e-05
# Val Loss: 0.08109
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 67/100, Train Loss: 0.06538, lr: 3.125e-05
# Val Loss: 0.08106
# ---------
# Epoch 68/100, Train Loss: 0.06536, lr: 3.125e-05
# Val Loss: 0.08104
# ---------
# Epoch 69/100, Train Loss: 0.06533, lr: 3.125e-05
# Val Loss: 0.08102
# ---------
# Epoch 70/100, Train Loss: 0.06531, lr: 3.125e-05
# Val Loss: 0.08099
# ---------
# Epoch 71/100, Train Loss: 0.06529, lr: 3.125e-05
# Val Loss: 0.08097
# ---------
# Early stopping ....
# 5.6410229206085205 [s]
# Epoch 1/100, Train Loss: 0.09289, lr: 0.001
# Val Loss: 0.09615
# ---------
# Epoch 2/100, Train Loss: 0.09255, lr: 0.001
# Val Loss: 0.09585
# ---------
# Epoch 3/100, Train Loss: 0.09224, lr: 0.001
# Val Loss: 0.09555
# ---------
# Epoch 4/100, Train Loss: 0.09190, lr: 0.001
# Val Loss: 0.09518
# ---------
# Epoch 5/100, Train Loss: 0.09146, lr: 0.001
# Val Loss: 0.09476
# ---------
# Epoch 6/100, Train Loss: 0.09093, lr: 0.001
# Val Loss: 0.09430
# ---------
# Epoch 7/100, Train Loss: 0.09027, lr: 0.001
# Val Loss: 0.09379
# ---------
# Epoch 8/100, Train Loss: 0.08945, lr: 0.001
# Val Loss: 0.09317
# ---------
# Epoch 9/100, Train Loss: 0.08841, lr: 0.001
# Val Loss: 0.09244
# ---------
# Epoch 10/100, Train Loss: 0.08713, lr: 0.001
# Val Loss: 0.09163
# ---------
# Epoch 11/100, Train Loss: 0.08572, lr: 0.001
# Val Loss: 0.09046
# ---------
# Epoch 12/100, Train Loss: 0.08423, lr: 0.001
# Val Loss: 0.08946
# ---------
# Epoch 13/100, Train Loss: 0.08307, lr: 0.001
# Val Loss: 0.08875
# ---------
# Epoch 14/100, Train Loss: 0.08195, lr: 0.001
# Val Loss: 0.08835
# ---------
# Epoch 15/100, Train Loss: 0.08076, lr: 0.001
# Val Loss: 0.08857
# ---------
# Epoch 16/100, Train Loss: 0.07983, lr: 0.001
# Val Loss: 0.08923
# ---------
# Epoch 17/100, Train Loss: 0.07995, lr: 0.001
# Val Loss: 0.08783
# ---------
# Epoch 18/100, Train Loss: 0.07883, lr: 0.001
# Val Loss: 0.08742
# ---------
# Epoch 19/100, Train Loss: 0.07882, lr: 0.001
# Val Loss: 0.08719
# ---------
# Epoch 20/100, Train Loss: 0.07833, lr: 0.001
# Val Loss: 0.08706
# ---------
# Epoch 21/100, Train Loss: 0.07746, lr: 0.001
# Val Loss: 0.08732
# ---------
# Epoch 22/100, Train Loss: 0.07705, lr: 0.001
# Val Loss: 0.08679
# ---------
# Epoch 23/100, Train Loss: 0.07625, lr: 0.001
# Val Loss: 0.08592
# ---------
# Epoch 24/100, Train Loss: 0.07539, lr: 0.001
# Val Loss: 0.08534
# ---------
# Epoch 25/100, Train Loss: 0.07471, lr: 0.001
# Val Loss: 0.08513
# ---------
# Epoch 26/100, Train Loss: 0.07393, lr: 0.001
# Val Loss: 0.08529
# ---------
# Epoch 27/100, Train Loss: 0.07349, lr: 0.001
# Val Loss: 0.08524
# ---------
# Epoch 28/100, Train Loss: 0.07329, lr: 0.001
# Val Loss: 0.08467
# ---------
# Epoch 29/100, Train Loss: 0.07296, lr: 0.001
# Val Loss: 0.08396
# ---------
# Epoch 30/100, Train Loss: 0.07255, lr: 0.001
# Val Loss: 0.08336
# ---------
# Epoch 31/100, Train Loss: 0.07193, lr: 0.001
# Val Loss: 0.08297
# ---------
# Epoch 32/100, Train Loss: 0.07136, lr: 0.001
# Val Loss: 0.08246
# ---------
# Epoch 33/100, Train Loss: 0.07076, lr: 0.001
# Val Loss: 0.08181
# ---------
# Epoch 34/100, Train Loss: 0.07009, lr: 0.001
# Val Loss: 0.08136
# ---------
# Epoch 35/100, Train Loss: 0.06948, lr: 0.001
# Val Loss: 0.08121
# ---------
# Epoch 36/100, Train Loss: 0.06877, lr: 0.001
# Val Loss: 0.08127
# ---------
# Epoch 37/100, Train Loss: 0.06824, lr: 0.001
# Val Loss: 0.08076
# ---------
# Epoch 38/100, Train Loss: 0.06773, lr: 0.001
# Val Loss: 0.07952
# ---------
# Epoch 39/100, Train Loss: 0.06718, lr: 0.001
# Val Loss: 0.07840
# ---------
# Epoch 40/100, Train Loss: 0.06659, lr: 0.001
# Val Loss: 0.07772
# ---------
# Epoch 41/100, Train Loss: 0.06609, lr: 0.001
# Val Loss: 0.07669
# ---------
# Epoch 42/100, Train Loss: 0.06571, lr: 0.001
# Val Loss: 0.07550
# ---------
# Epoch 43/100, Train Loss: 0.06532, lr: 0.001
# Val Loss: 0.07501
# ---------
# Epoch 44/100, Train Loss: 0.06477, lr: 0.001
# Val Loss: 0.07480
# ---------
# Epoch 45/100, Train Loss: 0.06429, lr: 0.001
# Val Loss: 0.07436
# ---------
# Epoch 46/100, Train Loss: 0.06391, lr: 0.001
# Val Loss: 0.07416
# ---------
# Epoch 47/100, Train Loss: 0.06349, lr: 0.001
# Val Loss: 0.07383
# ---------
# Epoch 48/100, Train Loss: 0.06309, lr: 0.001
# Val Loss: 0.07311
# ---------
# Epoch 49/100, Train Loss: 0.06271, lr: 0.001
# Val Loss: 0.07306
# ---------
# Epoch 50/100, Train Loss: 0.06231, lr: 0.001
# Val Loss: 0.07318
# ---------
# Epoch 51/100, Train Loss: 0.06188, lr: 0.001
# Val Loss: 0.07361
# ---------
# Epoch 52/100, Train Loss: 0.06149, lr: 0.001
# Val Loss: 0.07404
# ---------
# Epoch 53/100, Train Loss: 0.06116, lr: 0.001
# Val Loss: 0.07416
# ---------
# Epoch 54/100, Train Loss: 0.06084, lr: 0.001
# Val Loss: 0.07418
# ---------
# Epoch 55/100, Train Loss: 0.06046, lr: 0.001
# Val Loss: 0.07398
# ---------
# Epoch 56/100, Train Loss: 0.06007, lr: 0.001
# Val Loss: 0.07403
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 57/100, Train Loss: 0.05970, lr: 0.0005
# Val Loss: 0.07393
# ---------
# Epoch 58/100, Train Loss: 0.05948, lr: 0.0005
# Val Loss: 0.07391
# ---------
# Epoch 59/100, Train Loss: 0.05925, lr: 0.0005
# Val Loss: 0.07407
# ---------
# Epoch 60/100, Train Loss: 0.05899, lr: 0.0005
# Val Loss: 0.07420
# ---------
# Epoch 61/100, Train Loss: 0.05875, lr: 0.0005
# Val Loss: 0.07419
# ---------
# Epoch 62/100, Train Loss: 0.05851, lr: 0.0005
# Val Loss: 0.07425
# ---------
# Epoch 63/100, Train Loss: 0.05825, lr: 0.0005
# Val Loss: 0.07435
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 64/100, Train Loss: 0.05801, lr: 0.00025
# Val Loss: 0.07432
# ---------
# Epoch 65/100, Train Loss: 0.05789, lr: 0.00025
# Val Loss: 0.07425
# ---------
# Epoch 66/100, Train Loss: 0.05778, lr: 0.00025
# Val Loss: 0.07423
# ---------
# Epoch 67/100, Train Loss: 0.05768, lr: 0.00025
# Val Loss: 0.07430
# ---------
# Epoch 68/100, Train Loss: 0.05756, lr: 0.00025
# Val Loss: 0.07440
# ---------
# Epoch 69/100, Train Loss: 0.05745, lr: 0.00025
# Val Loss: 0.07446
# ---------
# Epoch 70/100, Train Loss: 0.05734, lr: 0.00025
# Val Loss: 0.07450
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 71/100, Train Loss: 0.05722, lr: 0.000125
# Val Loss: 0.07453
# ---------
# Epoch 72/100, Train Loss: 0.05717, lr: 0.000125
# Val Loss: 0.07458
# ---------
# Epoch 73/100, Train Loss: 0.05711, lr: 0.000125
# Val Loss: 0.07463
# ---------
# Epoch 74/100, Train Loss: 0.05706, lr: 0.000125
# Val Loss: 0.07468
# ---------
# Epoch 75/100, Train Loss: 0.05700, lr: 0.000125
# Val Loss: 0.07471
# ---------
# Epoch 76/100, Train Loss: 0.05694, lr: 0.000125
# Val Loss: 0.07470
# ---------
# Epoch 77/100, Train Loss: 0.05688, lr: 0.000125
# Val Loss: 0.07468
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 78/100, Train Loss: 0.05682, lr: 6.25e-05
# Val Loss: 0.07467
# ---------
# Epoch 79/100, Train Loss: 0.05679, lr: 6.25e-05
# Val Loss: 0.07466
# ---------
# Epoch 80/100, Train Loss: 0.05677, lr: 6.25e-05
# Val Loss: 0.07466
# ---------
# Epoch 81/100, Train Loss: 0.05673, lr: 6.25e-05
# Val Loss: 0.07466
# ---------
# Epoch 82/100, Train Loss: 0.05670, lr: 6.25e-05
# Val Loss: 0.07467
# ---------
# Epoch 83/100, Train Loss: 0.05667, lr: 6.25e-05
# Val Loss: 0.07467
# ---------
# Epoch 84/100, Train Loss: 0.05664, lr: 6.25e-05
# Val Loss: 0.07467
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 85/100, Train Loss: 0.05661, lr: 3.125e-05
# Val Loss: 0.07466
# ---------
# Epoch 86/100, Train Loss: 0.05660, lr: 3.125e-05
# Val Loss: 0.07466
# ---------
# Epoch 87/100, Train Loss: 0.05658, lr: 3.125e-05
# Val Loss: 0.07466
# ---------
# Epoch 88/100, Train Loss: 0.05656, lr: 3.125e-05
# Val Loss: 0.07466
# ---------
# Epoch 89/100, Train Loss: 0.05655, lr: 3.125e-05
# Val Loss: 0.07466
# ---------
# Early stopping ....
# 7.476091146469116 [s]
# Epoch 1/100, Train Loss: 0.09198, lr: 0.001
# Val Loss: 0.08631
# ---------
# Epoch 2/100, Train Loss: 0.09164, lr: 0.001
# Val Loss: 0.08612
# ---------
# Epoch 3/100, Train Loss: 0.09136, lr: 0.001
# Val Loss: 0.08598
# ---------
# Epoch 4/100, Train Loss: 0.09113, lr: 0.001
# Val Loss: 0.08584
# ---------
# Epoch 5/100, Train Loss: 0.09090, lr: 0.001
# Val Loss: 0.08568
# ---------
# Epoch 6/100, Train Loss: 0.09063, lr: 0.001
# Val Loss: 0.08550
# ---------
# Epoch 7/100, Train Loss: 0.09030, lr: 0.001
# Val Loss: 0.08530
# ---------
# Epoch 8/100, Train Loss: 0.08988, lr: 0.001
# Val Loss: 0.08508
# ---------
# Epoch 9/100, Train Loss: 0.08935, lr: 0.001
# Val Loss: 0.08484
# ---------
# Epoch 10/100, Train Loss: 0.08869, lr: 0.001
# Val Loss: 0.08459
# ---------
# Epoch 11/100, Train Loss: 0.08787, lr: 0.001
# Val Loss: 0.08433
# ---------
# Epoch 12/100, Train Loss: 0.08688, lr: 0.001
# Val Loss: 0.08413
# ---------
# Epoch 13/100, Train Loss: 0.08571, lr: 0.001
# Val Loss: 0.08409
# ---------
# Epoch 14/100, Train Loss: 0.08444, lr: 0.001
# Val Loss: 0.08397
# ---------
# Epoch 15/100, Train Loss: 0.08292, lr: 0.001
# Val Loss: 0.08355
# ---------
# Epoch 16/100, Train Loss: 0.08104, lr: 0.001
# Val Loss: 0.08299
# ---------
# Epoch 17/100, Train Loss: 0.07910, lr: 0.001
# Val Loss: 0.08277
# ---------
# Epoch 18/100, Train Loss: 0.07746, lr: 0.001
# Val Loss: 0.08309
# ---------
# Epoch 19/100, Train Loss: 0.07646, lr: 0.001
# Val Loss: 0.08247
# ---------
# Epoch 20/100, Train Loss: 0.07565, lr: 0.001
# Val Loss: 0.08187
# ---------
# Epoch 21/100, Train Loss: 0.07521, lr: 0.001
# Val Loss: 0.08209
# ---------
# Epoch 22/100, Train Loss: 0.07476, lr: 0.001
# Val Loss: 0.08226
# ---------
# Epoch 23/100, Train Loss: 0.07461, lr: 0.001
# Val Loss: 0.08208
# ---------
# Epoch 24/100, Train Loss: 0.07426, lr: 0.001
# Val Loss: 0.08207
# ---------
# Epoch 25/100, Train Loss: 0.07392, lr: 0.001
# Val Loss: 0.08216
# ---------
# Epoch 26/100, Train Loss: 0.07350, lr: 0.001
# Val Loss: 0.08193
# ---------
# Epoch 27/100, Train Loss: 0.07305, lr: 0.001
# Val Loss: 0.08150
# ---------
# Epoch 28/100, Train Loss: 0.07273, lr: 0.001
# Val Loss: 0.08128
# ---------
# Epoch 29/100, Train Loss: 0.07224, lr: 0.001
# Val Loss: 0.08120
# ---------
# Epoch 30/100, Train Loss: 0.07189, lr: 0.001
# Val Loss: 0.08084
# ---------
# Epoch 31/100, Train Loss: 0.07144, lr: 0.001
# Val Loss: 0.08087
# ---------
# Epoch 32/100, Train Loss: 0.07086, lr: 0.001
# Val Loss: 0.08091
# ---------
# Epoch 33/100, Train Loss: 0.07031, lr: 0.001
# Val Loss: 0.08035
# ---------
# Epoch 34/100, Train Loss: 0.06967, lr: 0.001
# Val Loss: 0.07976
# ---------
# Epoch 35/100, Train Loss: 0.06905, lr: 0.001
# Val Loss: 0.07910
# ---------
# Epoch 36/100, Train Loss: 0.06855, lr: 0.001
# Val Loss: 0.07828
# ---------
# Epoch 37/100, Train Loss: 0.06800, lr: 0.001
# Val Loss: 0.07814
# ---------
# Epoch 38/100, Train Loss: 0.06733, lr: 0.001
# Val Loss: 0.07768
# ---------
# Epoch 39/100, Train Loss: 0.06658, lr: 0.001
# Val Loss: 0.07702
# ---------
# Epoch 40/100, Train Loss: 0.06577, lr: 0.001
# Val Loss: 0.07657
# ---------
# Epoch 41/100, Train Loss: 0.06501, lr: 0.001
# Val Loss: 0.07628
# ---------
# Epoch 42/100, Train Loss: 0.06435, lr: 0.001
# Val Loss: 0.07661
# ---------
# Epoch 43/100, Train Loss: 0.06382, lr: 0.001
# Val Loss: 0.07690
# ---------
# Epoch 44/100, Train Loss: 0.06346, lr: 0.001
# Val Loss: 0.07620
# ---------
# Epoch 45/100, Train Loss: 0.06309, lr: 0.001
# Val Loss: 0.07616
# ---------
# Epoch 46/100, Train Loss: 0.06272, lr: 0.001
# Val Loss: 0.07551
# ---------
# Epoch 47/100, Train Loss: 0.06251, lr: 0.001
# Val Loss: 0.07589
# ---------
# Epoch 48/100, Train Loss: 0.06227, lr: 0.001
# Val Loss: 0.07467
# ---------
# Epoch 49/100, Train Loss: 0.06162, lr: 0.001
# Val Loss: 0.07433
# ---------
# Epoch 50/100, Train Loss: 0.06145, lr: 0.001
# Val Loss: 0.07528
# ---------
# Epoch 51/100, Train Loss: 0.06130, lr: 0.001
# Val Loss: 0.07467
# ---------
# Epoch 52/100, Train Loss: 0.06059, lr: 0.001
# Val Loss: 0.07392
# ---------
# Epoch 53/100, Train Loss: 0.06044, lr: 0.001
# Val Loss: 0.07456
# ---------
# Epoch 54/100, Train Loss: 0.06022, lr: 0.001
# Val Loss: 0.07446
# ---------
# Epoch 55/100, Train Loss: 0.05974, lr: 0.001
# Val Loss: 0.07345
# ---------
# Epoch 56/100, Train Loss: 0.05954, lr: 0.001
# Val Loss: 0.07366
# ---------
# Epoch 57/100, Train Loss: 0.05939, lr: 0.001
# Val Loss: 0.07369
# ---------
# Epoch 58/100, Train Loss: 0.05899, lr: 0.001
# Val Loss: 0.07318
# ---------
# Epoch 59/100, Train Loss: 0.05869, lr: 0.001
# Val Loss: 0.07324
# ---------
# Epoch 60/100, Train Loss: 0.05857, lr: 0.001
# Val Loss: 0.07312
# ---------
# Epoch 61/100, Train Loss: 0.05830, lr: 0.001
# Val Loss: 0.07285
# ---------
# Epoch 62/100, Train Loss: 0.05795, lr: 0.001
# Val Loss: 0.07171
# ---------
# Epoch 63/100, Train Loss: 0.05764, lr: 0.001
# Val Loss: 0.07312
# ---------
# Epoch 64/100, Train Loss: 0.05758, lr: 0.001
# Val Loss: 0.07101
# ---------
# Epoch 65/100, Train Loss: 0.05723, lr: 0.001
# Val Loss: 0.07239
# ---------
# Epoch 66/100, Train Loss: 0.05696, lr: 0.001
# Val Loss: 0.07120
# ---------
# Epoch 67/100, Train Loss: 0.05645, lr: 0.001
# Val Loss: 0.07153
# ---------
# Epoch 68/100, Train Loss: 0.05609, lr: 0.001
# Val Loss: 0.07094
# ---------
# Epoch 69/100, Train Loss: 0.05567, lr: 0.001
# Val Loss: 0.07330
# ---------
# Epoch 70/100, Train Loss: 0.05609, lr: 0.001
# Val Loss: 0.07095
# ---------
# Epoch 71/100, Train Loss: 0.05534, lr: 0.001
# Val Loss: 0.07228
# ---------
# Epoch 72/100, Train Loss: 0.05498, lr: 0.001
# Val Loss: 0.07321
# ---------
# Epoch 73/100, Train Loss: 0.05511, lr: 0.001
# Val Loss: 0.07065
# ---------
# Epoch 74/100, Train Loss: 0.05571, lr: 0.001
# Val Loss: 0.07172
# ---------
# Epoch 75/100, Train Loss: 0.05417, lr: 0.001
# Val Loss: 0.07175
# ---------
# Epoch 76/100, Train Loss: 0.05407, lr: 0.001
# Val Loss: 0.06913
# ---------
# Epoch 77/100, Train Loss: 0.05408, lr: 0.001
# Val Loss: 0.07132
# ---------
# Epoch 78/100, Train Loss: 0.05331, lr: 0.001
# Val Loss: 0.07108
# ---------
# Epoch 79/100, Train Loss: 0.05274, lr: 0.001
# Val Loss: 0.06911
# ---------
# Epoch 80/100, Train Loss: 0.05297, lr: 0.001
# Val Loss: 0.07232
# ---------
# Epoch 81/100, Train Loss: 0.05305, lr: 0.001
# Val Loss: 0.07184
# ---------
# Epoch 82/100, Train Loss: 0.05213, lr: 0.001
# Val Loss: 0.07111
# ---------
# Epoch 83/100, Train Loss: 0.05220, lr: 0.001
# Val Loss: 0.07030
# ---------
# Epoch 84/100, Train Loss: 0.05171, lr: 0.001
# Val Loss: 0.06995
# ---------
# Epoch 85/100, Train Loss: 0.05139, lr: 0.001
# Val Loss: 0.07040
# ---------
# Epoch 86/100, Train Loss: 0.05154, lr: 0.001
# Val Loss: 0.06955
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 87/100, Train Loss: 0.05095, lr: 0.0005
# Val Loss: 0.06948
# ---------
# Epoch 88/100, Train Loss: 0.05093, lr: 0.0005
# Val Loss: 0.06953
# ---------
# Epoch 89/100, Train Loss: 0.05054, lr: 0.0005
# Val Loss: 0.06973
# ---------
# Epoch 90/100, Train Loss: 0.05022, lr: 0.0005
# Val Loss: 0.07012
# ---------
# Epoch 91/100, Train Loss: 0.05031, lr: 0.0005
# Val Loss: 0.07016
# ---------
# Epoch 92/100, Train Loss: 0.05021, lr: 0.0005
# Val Loss: 0.06986
# ---------
# Epoch 93/100, Train Loss: 0.04985, lr: 0.0005
# Val Loss: 0.06969
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 94/100, Train Loss: 0.04978, lr: 0.00025
# Val Loss: 0.06966
# ---------
# Epoch 95/100, Train Loss: 0.04975, lr: 0.00025
# Val Loss: 0.06961
# ---------
# Epoch 96/100, Train Loss: 0.04964, lr: 0.00025
# Val Loss: 0.06955
# ---------
# Epoch 97/100, Train Loss: 0.04948, lr: 0.00025
# Val Loss: 0.06948
# ---------
# Epoch 98/100, Train Loss: 0.04938, lr: 0.00025
# Val Loss: 0.06938
# ---------
# Epoch 99/100, Train Loss: 0.04933, lr: 0.00025
# Val Loss: 0.06922
# ---------
# Epoch 100/100, Train Loss: 0.04926, lr: 0.00025
# Val Loss: 0.06902
# ---------
# 8.718750953674316 [s]
# Epoch 1/100, Train Loss: 0.09283, lr: 0.001
# Val Loss: 0.07792
# ---------
# Epoch 2/100, Train Loss: 0.09266, lr: 0.001
# Val Loss: 0.07800
# ---------
# Epoch 3/100, Train Loss: 0.09250, lr: 0.001
# Val Loss: 0.07807
# ---------
# Epoch 4/100, Train Loss: 0.09233, lr: 0.001
# Val Loss: 0.07813
# ---------
# Epoch 5/100, Train Loss: 0.09213, lr: 0.001
# Val Loss: 0.07817
# ---------
# Epoch 6/100, Train Loss: 0.09189, lr: 0.001
# Val Loss: 0.07824
# ---------
# Epoch 7/100, Train Loss: 0.09168, lr: 0.001
# Val Loss: 0.07827
# ---------
# Epoch 8/100, Train Loss: 0.09144, lr: 0.001
# Val Loss: 0.07822
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 9/100, Train Loss: 0.09111, lr: 0.0005
# Val Loss: 0.07817
# ---------
# Epoch 10/100, Train Loss: 0.09091, lr: 0.0005
# Val Loss: 0.07811
# ---------
# Epoch 11/100, Train Loss: 0.09068, lr: 0.0005
# Val Loss: 0.07804
# ---------
# Epoch 12/100, Train Loss: 0.09041, lr: 0.0005
# Val Loss: 0.07797
# ---------
# Epoch 13/100, Train Loss: 0.09016, lr: 0.0005
# Val Loss: 0.07790
# ---------
# Epoch 14/100, Train Loss: 0.08990, lr: 0.0005
# Val Loss: 0.07785
# ---------
# Epoch 15/100, Train Loss: 0.08963, lr: 0.0005
# Val Loss: 0.07782
# ---------
# Epoch 16/100, Train Loss: 0.08932, lr: 0.0005
# Val Loss: 0.07780
# ---------
# Epoch 17/100, Train Loss: 0.08896, lr: 0.0005
# Val Loss: 0.07781
# ---------
# Epoch 18/100, Train Loss: 0.08854, lr: 0.0005
# Val Loss: 0.07783
# ---------
# Epoch 19/100, Train Loss: 0.08808, lr: 0.0005
# Val Loss: 0.07789
# ---------
# Epoch 20/100, Train Loss: 0.08757, lr: 0.0005
# Val Loss: 0.07798
# ---------
# Epoch 21/100, Train Loss: 0.08700, lr: 0.0005
# Val Loss: 0.07811
# ---------
# Epoch 22/100, Train Loss: 0.08638, lr: 0.0005
# Val Loss: 0.07831
# ---------
# Epoch 23/100, Train Loss: 0.08569, lr: 0.0005
# Val Loss: 0.07861
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 24/100, Train Loss: 0.08495, lr: 0.00025
# Val Loss: 0.07880
# ---------
# Epoch 25/100, Train Loss: 0.08455, lr: 0.00025
# Val Loss: 0.07900
# ---------
# Epoch 26/100, Train Loss: 0.08413, lr: 0.00025
# Val Loss: 0.07919
# ---------
# Epoch 27/100, Train Loss: 0.08366, lr: 0.00025
# Val Loss: 0.07938
# ---------
# Epoch 28/100, Train Loss: 0.08316, lr: 0.00025
# Val Loss: 0.07957
# ---------
# Epoch 29/100, Train Loss: 0.08263, lr: 0.00025
# Val Loss: 0.07978
# ---------
# Epoch 30/100, Train Loss: 0.08207, lr: 0.00025
# Val Loss: 0.08000
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 31/100, Train Loss: 0.08149, lr: 0.000125
# Val Loss: 0.08012
# ---------
# Epoch 32/100, Train Loss: 0.08120, lr: 0.000125
# Val Loss: 0.08025
# ---------
# Epoch 33/100, Train Loss: 0.08090, lr: 0.000125
# Val Loss: 0.08038
# ---------
# Epoch 34/100, Train Loss: 0.08059, lr: 0.000125
# Val Loss: 0.08052
# ---------
# Epoch 35/100, Train Loss: 0.08028, lr: 0.000125
# Val Loss: 0.08068
# ---------
# Epoch 36/100, Train Loss: 0.07996, lr: 0.000125
# Val Loss: 0.08084
# ---------
# Epoch 37/100, Train Loss: 0.07963, lr: 0.000125
# Val Loss: 0.08101
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 38/100, Train Loss: 0.07930, lr: 6.25e-05
# Val Loss: 0.08110
# ---------
# Epoch 39/100, Train Loss: 0.07913, lr: 6.25e-05
# Val Loss: 0.08118
# ---------
# Epoch 40/100, Train Loss: 0.07896, lr: 6.25e-05
# Val Loss: 0.08125
# ---------
# Epoch 41/100, Train Loss: 0.07879, lr: 6.25e-05
# Val Loss: 0.08131
# ---------
# Epoch 42/100, Train Loss: 0.07862, lr: 6.25e-05
# Val Loss: 0.08136
# ---------
# Epoch 43/100, Train Loss: 0.07845, lr: 6.25e-05
# Val Loss: 0.08140
# ---------
# Epoch 44/100, Train Loss: 0.07827, lr: 6.25e-05
# Val Loss: 0.08142
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 45/100, Train Loss: 0.07810, lr: 3.125e-05
# Val Loss: 0.08143
# ---------
# Epoch 46/100, Train Loss: 0.07801, lr: 3.125e-05
# Val Loss: 0.08143
# ---------
# Epoch 47/100, Train Loss: 0.07792, lr: 3.125e-05
# Val Loss: 0.08142
# ---------
# Epoch 48/100, Train Loss: 0.07783, lr: 3.125e-05
# Val Loss: 0.08141
# ---------
# Epoch 49/100, Train Loss: 0.07774, lr: 3.125e-05
# Val Loss: 0.08140
# ---------
# Epoch 50/100, Train Loss: 0.07765, lr: 3.125e-05
# Val Loss: 0.08139
# ---------
# Epoch 51/100, Train Loss: 0.07756, lr: 3.125e-05
# Val Loss: 0.08138
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 52/100, Train Loss: 0.07747, lr: 1.5625e-05
# Val Loss: 0.08137
# ---------
# Epoch 53/100, Train Loss: 0.07743, lr: 1.5625e-05
# Val Loss: 0.08136
# ---------
# Epoch 54/100, Train Loss: 0.07738, lr: 1.5625e-05
# Val Loss: 0.08136
# ---------
# Epoch 55/100, Train Loss: 0.07734, lr: 1.5625e-05
# Val Loss: 0.08135
# ---------
# Epoch 56/100, Train Loss: 0.07729, lr: 1.5625e-05
# Val Loss: 0.08134
# ---------
# Early stopping ....
# 4.50662088394165 [s]
# Epoch 1/100, Train Loss: 0.09222, lr: 0.001
# Val Loss: 0.08688
# ---------
# Epoch 2/100, Train Loss: 0.09206, lr: 0.001
# Val Loss: 0.08687
# ---------
# Epoch 3/100, Train Loss: 0.09187, lr: 0.001
# Val Loss: 0.08686
# ---------
# Epoch 4/100, Train Loss: 0.09164, lr: 0.001
# Val Loss: 0.08687
# ---------
# Epoch 5/100, Train Loss: 0.09133, lr: 0.001
# Val Loss: 0.08689
# ---------
# Epoch 6/100, Train Loss: 0.09092, lr: 0.001
# Val Loss: 0.08691
# ---------
# Epoch 7/100, Train Loss: 0.09038, lr: 0.001
# Val Loss: 0.08694
# ---------
# Epoch 8/100, Train Loss: 0.08968, lr: 0.001
# Val Loss: 0.08703
# ---------
# Epoch 9/100, Train Loss: 0.08875, lr: 0.001
# Val Loss: 0.08727
# ---------
# Epoch 10/100, Train Loss: 0.08752, lr: 0.001
# Val Loss: 0.08774
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 11/100, Train Loss: 0.08586, lr: 0.0005
# Val Loss: 0.08807
# ---------
# Epoch 12/100, Train Loss: 0.08485, lr: 0.0005
# Val Loss: 0.08840
# ---------
# Epoch 13/100, Train Loss: 0.08372, lr: 0.0005
# Val Loss: 0.08862
# ---------
# Epoch 14/100, Train Loss: 0.08265, lr: 0.0005
# Val Loss: 0.08808
# ---------
# Epoch 15/100, Train Loss: 0.08167, lr: 0.0005
# Val Loss: 0.08705
# ---------
# Epoch 16/100, Train Loss: 0.08073, lr: 0.0005
# Val Loss: 0.08616
# ---------
# Epoch 17/100, Train Loss: 0.08002, lr: 0.0005
# Val Loss: 0.08561
# ---------
# Epoch 18/100, Train Loss: 0.07935, lr: 0.0005
# Val Loss: 0.08529
# ---------
# ...
# ---------
# Epoch 81/100, Train Loss: 0.06805, lr: 0.001
# Val Loss: 0.08271
# ---------
# Epoch 82/100, Train Loss: 0.06773, lr: 0.001
# Val Loss: 0.08182
# ---------
# Epoch 83/100, Train Loss: 0.06727, lr: 0.001
# Val Loss: 0.08260
# ---------
# Epoch 84/100, Train Loss: 0.06688, lr: 0.001
# Val Loss: 0.08164
# ---------
# Epoch 85/100, Train Loss: 0.06662, lr: 0.001
# Val Loss: 0.08201
# ---------
# Epoch 86/100, Train Loss: 0.06621, lr: 0.001
# Val Loss: 0.08161
# ---------
# Epoch 87/100, Train Loss: 0.06586, lr: 0.001
# Val Loss: 0.08099
# ---------
# Epoch 88/100, Train Loss: 0.06559, lr: 0.001
# Val Loss: 0.08171
# ---------
# Epoch 89/100, Train Loss: 0.06528, lr: 0.001
# Val Loss: 0.08039
# ---------
# Epoch 90/100, Train Loss: 0.06498, lr: 0.001
# Val Loss: 0.08166
# ---------
# Epoch 91/100, Train Loss: 0.06489, lr: 0.001
# Val Loss: 0.07893
# ---------
# Epoch 92/100, Train Loss: 0.06502, lr: 0.001
# Val Loss: 0.08137
# ---------
# Epoch 93/100, Train Loss: 0.06433, lr: 0.001
# Val Loss: 0.07983
# ---------
# Epoch 94/100, Train Loss: 0.06385, lr: 0.001
# Val Loss: 0.07937
# ---------
# Epoch 95/100, Train Loss: 0.06374, lr: 0.001
# Val Loss: 0.08093
# ---------
# Epoch 96/100, Train Loss: 0.06354, lr: 0.001
# Val Loss: 0.07869
# ---------
# Epoch 97/100, Train Loss: 0.06323, lr: 0.001
# Val Loss: 0.07973
# ---------
# Epoch 98/100, Train Loss: 0.06290, lr: 0.001
# Val Loss: 0.08040
# ---------
# Epoch 99/100, Train Loss: 0.06278, lr: 0.001
# Val Loss: 0.07807
# ---------
# Epoch 100/100, Train Loss: 0.06268, lr: 0.001
# Val Loss: 0.07974
# ---------
# 8.617863178253174 [s]
# Epoch 1/100, Train Loss: 0.10114, lr: 0.001
# Val Loss: 0.09609
# ---------
# Epoch 2/100, Train Loss: 0.10087, lr: 0.001
# Val Loss: 0.09603
# ---------
# Epoch 3/100, Train Loss: 0.10056, lr: 0.001
# Val Loss: 0.09599
# ---------
# Epoch 4/100, Train Loss: 0.10021, lr: 0.001
# Val Loss: 0.09596
# ---------
# Epoch 5/100, Train Loss: 0.09977, lr: 0.001
# Val Loss: 0.09600
# ---------
# Epoch 6/100, Train Loss: 0.09924, lr: 0.001
# Val Loss: 0.09622
# ---------
# Epoch 7/100, Train Loss: 0.09867, lr: 0.001
# Val Loss: 0.09668
# ---------
# Epoch 8/100, Train Loss: 0.09808, lr: 0.001
# Val Loss: 0.09726
# ---------
# Epoch 9/100, Train Loss: 0.09751, lr: 0.001
# Val Loss: 0.09763
# ---------
# Epoch 10/100, Train Loss: 0.09698, lr: 0.001
# Val Loss: 0.09743
# ---------
# Epoch 11/100, Train Loss: 0.09643, lr: 0.001
# Val Loss: 0.09687
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 12/100, Train Loss: 0.09588, lr: 0.0005
# Val Loss: 0.09655
# ---------
# Epoch 13/100, Train Loss: 0.09561, lr: 0.0005
# Val Loss: 0.09623
# ---------
# Epoch 14/100, Train Loss: 0.09536, lr: 0.0005
# Val Loss: 0.09593
# ---------
# Epoch 15/100, Train Loss: 0.09511, lr: 0.0005
# Val Loss: 0.09570
# ---------
# Epoch 16/100, Train Loss: 0.09488, lr: 0.0005
# Val Loss: 0.09552
# ---------
# Epoch 17/100, Train Loss: 0.09465, lr: 0.0005
# Val Loss: 0.09540
# ---------
# Epoch 18/100, Train Loss: 0.09441, lr: 0.0005
# Val Loss: 0.09534
# ---------
# Epoch 19/100, Train Loss: 0.09416, lr: 0.0005
# Val Loss: 0.09533
# ---------
# Epoch 20/100, Train Loss: 0.09390, lr: 0.0005
# Val Loss: 0.09538
# ---------
# Epoch 21/100, Train Loss: 0.09364, lr: 0.0005
# Val Loss: 0.09547
# ---------
# Epoch 22/100, Train Loss: 0.09339, lr: 0.0005
# Val Loss: 0.09559
# ---------
# Epoch 23/100, Train Loss: 0.09313, lr: 0.0005
# Val Loss: 0.09570
# ---------
# Epoch 24/100, Train Loss: 0.09289, lr: 0.0005
# Val Loss: 0.09577
# ---------
# Epoch 25/100, Train Loss: 0.09265, lr: 0.0005
# Val Loss: 0.09575
# ---------
# Epoch 26/100, Train Loss: 0.09241, lr: 0.0005
# Val Loss: 0.09565
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 27/100, Train Loss: 0.09217, lr: 0.00025
# Val Loss: 0.09557
# ---------
# Epoch 28/100, Train Loss: 0.09205, lr: 0.00025
# Val Loss: 0.09547
# ---------
# Epoch 29/100, Train Loss: 0.09192, lr: 0.00025
# Val Loss: 0.09536
# ---------
# Epoch 30/100, Train Loss: 0.09179, lr: 0.00025
# Val Loss: 0.09526
# ---------
# Epoch 31/100, Train Loss: 0.09165, lr: 0.00025
# Val Loss: 0.09518
# ---------
# Epoch 32/100, Train Loss: 0.09150, lr: 0.00025
# Val Loss: 0.09511
# ---------
# Epoch 33/100, Train Loss: 0.09136, lr: 0.00025
# Val Loss: 0.09507
# ---------
# Epoch 34/100, Train Loss: 0.09121, lr: 0.00025
# Val Loss: 0.09504
# ---------
# Epoch 35/100, Train Loss: 0.09106, lr: 0.00025
# Val Loss: 0.09502
# ---------
# Epoch 36/100, Train Loss: 0.09092, lr: 0.00025
# Val Loss: 0.09500
# ---------
# Epoch 37/100, Train Loss: 0.09077, lr: 0.00025
# Val Loss: 0.09497
# ---------
# Epoch 38/100, Train Loss: 0.09063, lr: 0.00025
# Val Loss: 0.09494
# ---------
# Epoch 39/100, Train Loss: 0.09048, lr: 0.00025
# Val Loss: 0.09490
# ---------
# Epoch 40/100, Train Loss: 0.09034, lr: 0.00025
# Val Loss: 0.09487
# ---------
# Epoch 41/100, Train Loss: 0.09020, lr: 0.00025
# Val Loss: 0.09485
# ---------
# Epoch 42/100, Train Loss: 0.09007, lr: 0.00025
# Val Loss: 0.09484
# ---------
# Epoch 43/100, Train Loss: 0.08993, lr: 0.00025
# Val Loss: 0.09484
# ---------
# Epoch 44/100, Train Loss: 0.08980, lr: 0.00025
# Val Loss: 0.09483
# ---------
# Epoch 45/100, Train Loss: 0.08967, lr: 0.00025
# Val Loss: 0.09481
# ---------
# Epoch 46/100, Train Loss: 0.08955, lr: 0.00025
# Val Loss: 0.09480
# ---------
# Epoch 47/100, Train Loss: 0.08942, lr: 0.00025
# Val Loss: 0.09485
# ---------
# Epoch 48/100, Train Loss: 0.08929, lr: 0.00025
# Val Loss: 0.09491
# ---------
# Epoch 49/100, Train Loss: 0.08915, lr: 0.00025
# Val Loss: 0.09490
# ---------
# Epoch 50/100, Train Loss: 0.08902, lr: 0.00025
# Val Loss: 0.09493
# ---------
# Epoch 51/100, Train Loss: 0.08888, lr: 0.00025
# Val Loss: 0.09500
# ---------
# Epoch 52/100, Train Loss: 0.08875, lr: 0.00025
# Val Loss: 0.09492
# ---------
# Epoch 53/100, Train Loss: 0.08862, lr: 0.00025
# Val Loss: 0.09505
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 54/100, Train Loss: 0.08850, lr: 0.000125
# Val Loss: 0.09499
# ---------
# Epoch 55/100, Train Loss: 0.08844, lr: 0.000125
# Val Loss: 0.09492
# ---------
# Epoch 56/100, Train Loss: 0.08838, lr: 0.000125
# Val Loss: 0.09499
# ---------
# Epoch 57/100, Train Loss: 0.08831, lr: 0.000125
# Val Loss: 0.09507
# ---------
# Epoch 58/100, Train Loss: 0.08825, lr: 0.000125
# Val Loss: 0.09505
# ---------
# Epoch 59/100, Train Loss: 0.08818, lr: 0.000125
# Val Loss: 0.09499
# ---------
# Epoch 60/100, Train Loss: 0.08812, lr: 0.000125
# Val Loss: 0.09500
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 61/100, Train Loss: 0.08805, lr: 6.25e-05
# Val Loss: 0.09504
# ---------
# Epoch 62/100, Train Loss: 0.08802, lr: 6.25e-05
# Val Loss: 0.09508
# ---------
# Epoch 63/100, Train Loss: 0.08799, lr: 6.25e-05
# Val Loss: 0.09510
# ---------
# Epoch 64/100, Train Loss: 0.08796, lr: 6.25e-05
# Val Loss: 0.09508
# ---------
# Epoch 65/100, Train Loss: 0.08792, lr: 6.25e-05
# Val Loss: 0.09504
# ---------
# Epoch 66/100, Train Loss: 0.08789, lr: 6.25e-05
# Val Loss: 0.09503
# ---------
# Epoch 67/100, Train Loss: 0.08786, lr: 6.25e-05
# Val Loss: 0.09505
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 68/100, Train Loss: 0.08783, lr: 3.125e-05
# Val Loss: 0.09507
# ---------
# Epoch 69/100, Train Loss: 0.08781, lr: 3.125e-05
# Val Loss: 0.09508
# ---------
# Epoch 70/100, Train Loss: 0.08780, lr: 3.125e-05
# Val Loss: 0.09509
# ---------
# Epoch 71/100, Train Loss: 0.08778, lr: 3.125e-05
# Val Loss: 0.09509
# ---------
# Epoch 72/100, Train Loss: 0.08776, lr: 3.125e-05
# Val Loss: 0.09508
# ---------
# Epoch 73/100, Train Loss: 0.08775, lr: 3.125e-05
# Val Loss: 0.09506
# ---------
# Epoch 74/100, Train Loss: 0.08773, lr: 3.125e-05
# Val Loss: 0.09505
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 75/100, Train Loss: 0.08772, lr: 1.5625e-05
# Val Loss: 0.09505
# ---------
# Epoch 76/100, Train Loss: 0.08771, lr: 1.5625e-05
# Val Loss: 0.09505
# ---------
# Epoch 77/100, Train Loss: 0.08770, lr: 1.5625e-05
# Val Loss: 0.09506
# ---------
# Epoch 78/100, Train Loss: 0.08769, lr: 1.5625e-05
# Val Loss: 0.09506
# ---------
# Epoch 79/100, Train Loss: 0.08768, lr: 1.5625e-05
# Val Loss: 0.09507
# ---------
# Epoch 80/100, Train Loss: 0.08767, lr: 1.5625e-05
# Val Loss: 0.09507
# ---------
# Epoch 81/100, Train Loss: 0.08767, lr: 1.5625e-05
# Val Loss: 0.09507
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 82/100, Train Loss: 0.08766, lr: 7.8125e-06
# Val Loss: 0.09507
# ---------
# Epoch 83/100, Train Loss: 0.08765, lr: 7.8125e-06
# Val Loss: 0.09507
# ---------
# Epoch 84/100, Train Loss: 0.08765, lr: 7.8125e-06
# Val Loss: 0.09507
# ---------
# Epoch 85/100, Train Loss: 0.08765, lr: 7.8125e-06
# Val Loss: 0.09506
# ---------
# Epoch 86/100, Train Loss: 0.08764, lr: 7.8125e-06
# Val Loss: 0.09506
# ---------
# Early stopping ....
# 7.110381126403809 [s]
# Epoch 1/100, Train Loss: 0.09435, lr: 0.001
# Val Loss: 0.09918
# ---------
# Epoch 2/100, Train Loss: 0.09415, lr: 0.001
# Val Loss: 0.09895
# ---------
# Epoch 3/100, Train Loss: 0.09398, lr: 0.001
# Val Loss: 0.09870
# ---------
# Epoch 4/100, Train Loss: 0.09379, lr: 0.001
# Val Loss: 0.09847
# ---------
# Epoch 5/100, Train Loss: 0.09361, lr: 0.001
# Val Loss: 0.09828
# ---------
# Epoch 6/100, Train Loss: 0.09344, lr: 0.001
# Val Loss: 0.09804
# ---------
# Epoch 7/100, Train Loss: 0.09321, lr: 0.001
# Val Loss: 0.09770
# ---------
# Epoch 8/100, Train Loss: 0.09286, lr: 0.001
# Val Loss: 0.09719
# ---------
# Epoch 9/100, Train Loss: 0.09237, lr: 0.001
# Val Loss: 0.09641
# ---------
# Epoch 10/100, Train Loss: 0.09170, lr: 0.001
# Val Loss: 0.09527
# ---------
# Epoch 11/100, Train Loss: 0.09076, lr: 0.001
# Val Loss: 0.09366
# ---------
# Epoch 12/100, Train Loss: 0.08944, lr: 0.001
# Val Loss: 0.09179
# ---------
# Epoch 13/100, Train Loss: 0.08759, lr: 0.001
# Val Loss: 0.09267
# ---------
# Epoch 14/100, Train Loss: 0.08792, lr: 0.001
# Val Loss: 0.09200
# ---------
# Epoch 15/100, Train Loss: 0.08619, lr: 0.001
# Val Loss: 0.09218
# ---------
# Epoch 16/100, Train Loss: 0.08507, lr: 0.001
# Val Loss: 0.09260
# ---------
# Epoch 17/100, Train Loss: 0.08441, lr: 0.001
# Val Loss: 0.09190
# ---------
# Epoch 18/100, Train Loss: 0.08326, lr: 0.001
# Val Loss: 0.08988
# ---------
# Epoch 19/100, Train Loss: 0.08159, lr: 0.001
# Val Loss: 0.08704
# ---------
# Epoch 20/100, Train Loss: 0.07980, lr: 0.001
# Val Loss: 0.08438
# ---------
# Epoch 21/100, Train Loss: 0.07808, lr: 0.001
# Val Loss: 0.08234
# ---------
# Epoch 22/100, Train Loss: 0.07644, lr: 0.001
# Val Loss: 0.08119
# ---------
# Epoch 23/100, Train Loss: 0.07465, lr: 0.001
# Val Loss: 0.08146
# ---------
# Epoch 24/100, Train Loss: 0.07383, lr: 0.001
# Val Loss: 0.08070
# ---------
# Epoch 25/100, Train Loss: 0.07280, lr: 0.001
# Val Loss: 0.07933
# ---------
# Epoch 26/100, Train Loss: 0.07176, lr: 0.001
# Val Loss: 0.07850
# ---------
# Epoch 27/100, Train Loss: 0.07036, lr: 0.001
# Val Loss: 0.07831
# ---------
# Epoch 28/100, Train Loss: 0.06861, lr: 0.001
# Val Loss: 0.07824
# ---------
# Epoch 29/100, Train Loss: 0.06732, lr: 0.001
# Val Loss: 0.07725
# ---------
# Epoch 30/100, Train Loss: 0.06551, lr: 0.001
# Val Loss: 0.07686
# ---------
# Epoch 31/100, Train Loss: 0.06389, lr: 0.001
# Val Loss: 0.07814
# ---------
# Epoch 32/100, Train Loss: 0.06252, lr: 0.001
# Val Loss: 0.07867
# ---------
# Epoch 33/100, Train Loss: 0.06094, lr: 0.001
# Val Loss: 0.07715
# ---------
# Epoch 34/100, Train Loss: 0.05979, lr: 0.001
# Val Loss: 0.07599
# ---------
# Epoch 35/100, Train Loss: 0.05894, lr: 0.001
# Val Loss: 0.07614
# ---------
# Epoch 36/100, Train Loss: 0.05842, lr: 0.001
# Val Loss: 0.07524
# ---------
# Epoch 37/100, Train Loss: 0.05789, lr: 0.001
# Val Loss: 0.07634
# ---------
# Epoch 38/100, Train Loss: 0.05723, lr: 0.001
# Val Loss: 0.07538
# ---------
# Epoch 39/100, Train Loss: 0.05653, lr: 0.001
# Val Loss: 0.07468
# ---------
# Epoch 40/100, Train Loss: 0.05563, lr: 0.001
# Val Loss: 0.07482
# ---------
# Epoch 41/100, Train Loss: 0.05531, lr: 0.001
# Val Loss: 0.07494
# ---------
# Epoch 42/100, Train Loss: 0.05497, lr: 0.001
# Val Loss: 0.07591
# ---------
# Epoch 43/100, Train Loss: 0.05461, lr: 0.001
# Val Loss: 0.07449
# ---------
# Epoch 44/100, Train Loss: 0.05397, lr: 0.001
# Val Loss: 0.07491
# ---------
# Epoch 45/100, Train Loss: 0.05363, lr: 0.001
# Val Loss: 0.07310
# ---------
# Epoch 46/100, Train Loss: 0.05306, lr: 0.001
# Val Loss: 0.07395
# ---------
# Epoch 47/100, Train Loss: 0.05268, lr: 0.001
# Val Loss: 0.07387
# ---------
# Epoch 48/100, Train Loss: 0.05234, lr: 0.001
# Val Loss: 0.07354
# ---------
# Epoch 49/100, Train Loss: 0.05206, lr: 0.001
# Val Loss: 0.07355
# ---------
# Epoch 50/100, Train Loss: 0.05190, lr: 0.001
# Val Loss: 0.07291
# ---------
# Epoch 51/100, Train Loss: 0.05180, lr: 0.001
# Val Loss: 0.07463
# ---------
# Epoch 52/100, Train Loss: 0.05190, lr: 0.001
# Val Loss: 0.07220
# ---------
# Epoch 53/100, Train Loss: 0.05152, lr: 0.001
# Val Loss: 0.07364
# ---------
# Epoch 54/100, Train Loss: 0.05114, lr: 0.001
# Val Loss: 0.07246
# ---------
# Epoch 55/100, Train Loss: 0.05053, lr: 0.001
# Val Loss: 0.07153
# ---------
# Epoch 56/100, Train Loss: 0.05082, lr: 0.001
# Val Loss: 0.07316
# ---------
# Epoch 57/100, Train Loss: 0.05081, lr: 0.001
# Val Loss: 0.07169
# ---------
# Epoch 58/100, Train Loss: 0.05004, lr: 0.001
# Val Loss: 0.07095
# ---------
# Epoch 59/100, Train Loss: 0.05046, lr: 0.001
# Val Loss: 0.07309
# ---------
# Epoch 60/100, Train Loss: 0.05023, lr: 0.001
# Val Loss: 0.07203
# ---------
# Epoch 61/100, Train Loss: 0.04957, lr: 0.001
# Val Loss: 0.07067
# ---------
# Epoch 62/100, Train Loss: 0.05010, lr: 0.001
# Val Loss: 0.07216
# ---------
# Epoch 63/100, Train Loss: 0.04928, lr: 0.001
# Val Loss: 0.07263
# ---------
# Epoch 64/100, Train Loss: 0.04935, lr: 0.001
# Val Loss: 0.07106
# ---------
# Epoch 65/100, Train Loss: 0.04925, lr: 0.001
# Val Loss: 0.07132
# ---------
# Epoch 66/100, Train Loss: 0.04885, lr: 0.001
# Val Loss: 0.07266
# ---------
# Epoch 67/100, Train Loss: 0.04909, lr: 0.001
# Val Loss: 0.07154
# ---------
# Epoch 68/100, Train Loss: 0.04851, lr: 0.001
# Val Loss: 0.07072
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 69/100, Train Loss: 0.04876, lr: 0.0005
# Val Loss: 0.07121
# ---------
# Epoch 70/100, Train Loss: 0.04834, lr: 0.0005
# Val Loss: 0.07210
# ---------
# Epoch 71/100, Train Loss: 0.04848, lr: 0.0005
# Val Loss: 0.07205
# ---------
# Epoch 72/100, Train Loss: 0.04841, lr: 0.0005
# Val Loss: 0.07117
# ---------
# Epoch 73/100, Train Loss: 0.04812, lr: 0.0005
# Val Loss: 0.07073
# ---------
# Epoch 74/100, Train Loss: 0.04829, lr: 0.0005
# Val Loss: 0.07113
# ---------
# Epoch 75/100, Train Loss: 0.04804, lr: 0.0005
# Val Loss: 0.07191
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 76/100, Train Loss: 0.04804, lr: 0.00025
# Val Loss: 0.07190
# ---------
# Epoch 77/100, Train Loss: 0.04802, lr: 0.00025
# Val Loss: 0.07151
# ---------
# Epoch 78/100, Train Loss: 0.04787, lr: 0.00025
# Val Loss: 0.07108
# ---------
# Epoch 79/100, Train Loss: 0.04787, lr: 0.00025
# Val Loss: 0.07091
# ---------
# Epoch 80/100, Train Loss: 0.04791, lr: 0.00025
# Val Loss: 0.07105
# ---------
# Epoch 81/100, Train Loss: 0.04782, lr: 0.00025
# Val Loss: 0.07140
# ---------
# Epoch 82/100, Train Loss: 0.04774, lr: 0.00025
# Val Loss: 0.07168
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 83/100, Train Loss: 0.04777, lr: 0.000125
# Val Loss: 0.07166
# ---------
# Epoch 84/100, Train Loss: 0.04776, lr: 0.000125
# Val Loss: 0.07149
# ---------
# Epoch 85/100, Train Loss: 0.04770, lr: 0.000125
# Val Loss: 0.07126
# ---------
# Epoch 86/100, Train Loss: 0.04766, lr: 0.000125
# Val Loss: 0.07106
# ---------
# Epoch 87/100, Train Loss: 0.04766, lr: 0.000125
# Val Loss: 0.07095
# ---------
# Epoch 88/100, Train Loss: 0.04767, lr: 0.000125
# Val Loss: 0.07095
# ---------
# Epoch 89/100, Train Loss: 0.04765, lr: 0.000125
# Val Loss: 0.07105
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 90/100, Train Loss: 0.04761, lr: 6.25e-05
# Val Loss: 0.07112
# ---------
# Epoch 91/100, Train Loss: 0.04759, lr: 6.25e-05
# Val Loss: 0.07120
# ---------
# Epoch 92/100, Train Loss: 0.04759, lr: 6.25e-05
# Val Loss: 0.07127
# ---------
# Epoch 93/100, Train Loss: 0.04758, lr: 6.25e-05
# Val Loss: 0.07131
# ---------
# Epoch 94/100, Train Loss: 0.04758, lr: 6.25e-05
# Val Loss: 0.07132
# ---------
# Epoch 95/100, Train Loss: 0.04757, lr: 6.25e-05
# Val Loss: 0.07130
# ---------
# Epoch 96/100, Train Loss: 0.04756, lr: 6.25e-05
# Val Loss: 0.07124
# ---------
#
# [Callback] Adjusting lr. Counter: 7
#
# Epoch 97/100, Train Loss: 0.04755, lr: 3.125e-05
# Val Loss: 0.07121
# ---------
# Epoch 98/100, Train Loss: 0.04754, lr: 3.125e-05
# Val Loss: 0.07117
# ---------
# Epoch 99/100, Train Loss: 0.04754, lr: 3.125e-05
# Val Loss: 0.07114
# ---------
# Epoch 100/100, Train Loss: 0.04753, lr: 3.125e-05
# Val Loss: 0.07111
# ---------
# 7.665647983551025 [s]
# Metrics collected. [5.321385947812859, 7.456101220321567, 0.36366749759936384, 2.3772763760231, 2.6322654515711883, 0.2469036705203734]
