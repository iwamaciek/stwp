# %%
import sys
sys.path.append("..")
from hpo import HPO

# %%
params = {
'baseline_type' : 'lgbm',
'n_trials' : 1,
'dataset' : '../../data2022_full.grib',
'sequence_n_trials' : 1,
'fh_n_trials' : 1
}

# %%
hpo = HPO(**params)

# %%
hpo.run_and_report()
# Out:
# [I 2023-12-05 13:03:17,467] A new study created in memory with name: no-name-89f1b607-347f-480c-81f8-3c873818f39c
# /Users/piotr/anaconda3/envs/engeneeringEnv/lib/python3.10/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/piotr/anaconda3/envs/engeneeringEnv/lib/python3.10/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/piotr/anaconda3/envs/engeneeringEnv/lib/python3.10/site-packages/sklearn/utils/validation.py:1183: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
# ...

# %%
hpo.run_fh_study()

# %%
hpo.report()
# Out:
# Best s => 9
# Best parameters:
# alpha : 0.449015214815822
# regressor_type : ridge
# Best fh=> 1
