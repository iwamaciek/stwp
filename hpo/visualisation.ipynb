# %%
import sys
sys.path.append("..")
from visualisation import Visualization
# Out:
# d:\Piotr\inzynierka\meteoapp-data\venv\lib\site-packages\gribapi\__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.27.0
#   warnings.warn(

# %%
viz = Visualization()

# %%
viz.read_plots_from_json(file_name="modelsplots_best_for_now.json")

# %%
viz.plot_data_sequence(one_plot=True)

# %%
viz.plot_data_sequence_time(one_plot=True)

# %%
viz.plot_data_fh(one_plot=True)

# %%
viz.plot_data_fh_time(one_plot=True)

# %%
viz.create_metrics_table()
# Out:
# ╒═══════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ cnn           │ [1.685922387179955, 1.5747887334540158, 0.2887887369345566, 1.2364932050973096, 1.206218932062727, 0.28941713416653]        │
# ├───────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ gnn           │ [0.19019146209265816, 0.051294426244214916, 0.781708749110107, 0.3425071116008582, 0.39770034334033527, 1.0387445135305597] │
# ├───────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ simple-linear │ [2.037262893706794, 1.4003665866603896, 0.29471925150595585, 1.5572344524320676, 1.5235950252831623, 0.3023291238712628]    │
# ...

# %%
viz.plot_not_normalized_data_sequence(for_features=True, one_plot=True)

# %%
viz.plot_months(one_plot=True)

# %%
viz.plot_gnn_layers()

# %%
viz.plot_not_normalized_data_fh(for_features=True, one_plot=True)

# %%
viz.plot_error_maps()
