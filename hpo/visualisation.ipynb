# %%
import sys
sys.path.append("..")
from visualisation import Visualization

# %%
viz = Visualization()

# %%
viz.read_plots_from_json()

# %%
viz.plot_data_sequence(one_plot=True)

# %%
viz.plot_data_sequence_time(one_plot=True)

# %%
viz.plot_data_fh(one_plot=True)

# %%
viz.plot_data_fh_time(one_plot=False)

# %%
viz.create_metrics_table()
# Out:
# ╒═══════════════╤═════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ cnn           │ [1.685922387179955, 1.5747887334540158, 0.2887887369345566, 1.2364932050973096, 1.206218932062727, 0.28941713416653]        │
# ├───────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ gnn           │ [0.19019146209265816, 0.051294426244214916, 0.781708749110107, 0.3425071116008582, 0.39770034334033527, 1.0387445135305597] │
# ├───────────────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ simple-linear │ [2.0372628936824584, 1.4003665841739397, 0.29471925147261513, 1.5572344521252266, 1.5235950251361972, 0.30232912418487257]  │
# ...

# %%
viz.plot_not_normalized_data_sequence(for_features=True
)

# %%
viz.plot_months(one_plot=True)
