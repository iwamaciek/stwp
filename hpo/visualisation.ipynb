# %%
import sys
sys.path.append("..")
from visualisation import Visualization
# Out:
# d:\Piotr\inzynierka\meteoapp-data\venv\lib\site-packages\gribapi\__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.27.0
#   warnings.warn(

# %%
viz = Visualization()

# %%
viz.read_plots_from_json(file_name="modelsplots_best.json")

# %%
viz.plot_data_sequence(one_plot=True, save='data_sequence')

# %%
viz.plot_data_sequence_time(one_plot=True, save='data_sequence_time')

# %%
viz.plot_data_fh(one_plot=True, save='data_fh')

# %%
viz.plot_data_fh_time(one_plot=True, save='data_fh_time')

# %%
viz.create_metrics_table()
# Out:
# ╒═══════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ cnn           │ [1.685922387179955, 1.5747887334540158, 0.2887887369345566, 1.2364932050973096, 1.206218932062727, 0.28941713416653]      │
# ├───────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ gnn           │ [0.192998232320569, 0.04926109191540771, 0.7616174443576543, 0.3390093050252741, 0.38925249126034583, 1.0734766607579924] │
# ├───────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ simple-linear │ [2.037262893706794, 1.4003665866603896, 0.29471925150595585, 1.5572344524320676, 1.5235950252831623, 0.3023291238712628]  │
# ...

# %%
viz.plot_not_normalized_data_sequence(for_features=True, one_plot=True, save='not_normalized_data_sequence')

# %%
viz.plot_months(one_plot=True, save='months')

# %%
viz.plot_gnn_layers(save='gnn_layers')

# %%
viz.plot_not_normalized_data_fh(for_features=True, one_plot=True, save='not_normalized_data_fh')
