# %%
import sys
sys.path.append("..")
from hpo import HPO
from models.config import config as cfg
from visualisation import Visualization
# Out:
# /Users/piotrwojsznis/Library/Python/3.9/lib/python/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.30.0
#   warnings.warn(
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 import sys
#       2 sys.path.append("..")
# ----> 3 from hpo import HPO
#       4 from models.config import config as cfg
#       5 from visualisation import Visualization
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/hpo.py:16
#      12 import sys
#      14 sys.path.append("..")
# ---> 16 from models.data_processor import DataProcessor
#      17 from models.linear_reg.linear_regressor import LinearRegressor
#      18 from models.linear_reg.simple_linear_regressor import SimpleLinearRegressor
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/data_processor.py:9
#       7 from utils.trig_encode import trig_encode
#       8 from sklearn.utils import shuffle
# ----> 9 from models.config import config as cfg
#      10 from utils.get_data import BIG_AREA, SMALL_AREA
#      13 class DataProcessor:
#
# File ~/Documents/Studia/inzynierka/meteoapp-data/hpo/../models/config.py:1
# ----> 1 import torch
#       4 class Config:
#       5     DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/__init__.py:1332
#    1329 py_int = int
#    1331 # Shared memory manager needs to know the exact location of manager executable
# -> 1332 _C._initExtension(manager_path())
#    1333 del manager_path
#    1335 # Appease the type checker: it can't deal with direct setting of globals().
#    1336 # Note that we will see "too many" functions when reexporting this way; there
#    1337 # is not a good way to fix this problem.  Perhaps, try to redesign VariableFunctions
#    1338 # so that this import is good enough
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/cuda/__init__.py:1272
#    1263     if has_triton:
#    1264         torch._TritonLibrary.registerOp(
#    1265             "_triton_bsr_dense_mm_out",
#    1266             "_triton_bsr_dense_mm_out(Tensor bsr, Tensor dense, *, Tensor(a!) out) -> Tensor(a!)",
#    1267             kernel_impl,
#    1268             "SparseCsrCUDA",
#    1269         )
# -> 1272 _lazy_call(_register_triton_kernels)
#    1275 from . import amp, jiterator, nvtx, profiler, sparse
#    1277 __all__ = [
#    1278     # Typed storage and tensors
#    1279     "BFloat16Storage",
#    (...)
#    1389     "utilization",
#    1390 ]
#
# File ~/Library/Python/3.9/lib/python/site-packages/torch/cuda/__init__.py:241, in _lazy_call(callable, **kwargs)
#     238     _lazy_seed_tracker.queue_seed(callable, traceback.format_stack())
#     239 else:
#     240     # Don't store the actual traceback to avoid memory cycle
# --> 241     _queued_calls.append((callable, traceback.format_stack()))
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/traceback.py:197, in format_stack(f, limit)
#     195 if f is None:
#     196     f = sys._getframe().f_back
# --> 197 return format_list(extract_stack(f, limit=limit))
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/traceback.py:211, in extract_stack(f, limit)
#     209 if f is None:
#     210     f = sys._getframe().f_back
# --> 211 stack = StackSummary.extract(walk_stack(f), limit=limit)
#     212 stack.reverse()
#     213 return stack
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/traceback.py:366, in StackSummary.extract(klass, frame_gen, limit, lookup_lines, capture_locals)
#     364 if lookup_lines:
#     365     for f in result:
# --> 366         f.line
#     367 return result
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/traceback.py:288, in FrameSummary.line(self)
#     285 @property
#     286 def line(self):
#     287     if self._line is None:
# --> 288         self._line = linecache.getline(self.filename, self.lineno).strip()
#     289     return self._line
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/linecache.py:30, in getline(filename, lineno, module_globals)
#      26 def getline(filename, lineno, module_globals=None):
#      27     """Get a line for a Python source file from the cache.
#      28     Update the cache if it doesn't contain an entry for this file already."""
# ---> 30     lines = getlines(filename, module_globals)
#      31     if 1 <= lineno <= len(lines):
#      32         return lines[lineno - 1]
#
# File /Applications/Xcode.app/Contents/Developer/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/linecache.py:54, in getlines(filename, module_globals)
#      52     continue
#      53 for mod in mods:
# ---> 54     if getattr(mod, '__file__', None) == filename:
#      55         module_globals = mod.__dict__
#      56         break
#
# KeyboardInterrupt:

# %%
viz = Visualization()

# %%
viz.read_plots_from_json()

# %%
viz.plot_data_sequence(one_plot=True)

# %%
viz.plot_data_sequence_time(one_plot=True)

# %%
viz.plot_data_fh(one_plot=True)

# %%
viz.plot_data_fh_time(one_plot=True)

# %%
viz.create_metrics_table()
# Out:
# ╒═════╤══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ gnn │ [4.9567815917908185, 5.63119460912924, 0.356821863188582, 1.9927627236741343, 2.838695810412014, 0.2485296317964708] │
# ├─────┼──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ cnn │ [5.321385947812859, 7.456101220321567, 0.36366749759936384, 2.3772763760231, 2.6322654515711883, 0.2469036705203734] │
# ╘═════╧══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╛

# %%
viz.plot_not_normalized_data_sequence()

# %%
viz.plot_not_normalized_data_fh()
