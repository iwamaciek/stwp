# %%
import sys
sys.path.append("..")
from hpo import HPO
from models.config import config as cfg
from visualisation import Visualization
# Out:
# /Users/piotrwojsznis/Library/Python/3.9/lib/python/site-packages/gribapi/__init__.py:23: UserWarning: ecCodes 2.31.0 or higher is recommended. You are running version 2.30.0
#   warnings.warn(
# /Users/piotrwojsznis/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
viz = Visualization()

# %%
viz.read_plots_from_json()

# %%
viz.plot_data_sequence(one_plot=True)

# %%
viz.plot_data_sequence_time(one_plot=True)

# %%
viz.plot_data_fh(one_plot=True)

# %%
viz.plot_data_fh_time(one_plot=True)

# %%
viz.create_metrics_table()
# Out:
# ╒═══════════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╕
# │ gnn           │ [4.9567815917908185, 5.63119460912924, 0.356821863188582, 1.9927627236741343, 2.838695810412014, 0.2485296317964708]      │
# ├───────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ cnn           │ [5.321385947812859, 7.456101220321567, 0.36366749759936384, 2.3772763760231, 2.6322654515711883, 0.2469036705203734]      │
# ├───────────────┼───────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────┤
# │ simple-linear │ [0.24310028895494618, 0.05840420070807855, 0.8016004288465556, 0.4900992651135682, 0.561896953972444, 1.0860234388939864] │
# ╘═══════════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════════════════════════════╛

# %%
viz.plot_not_normalized_data_sequence(for_features=False
)

# %%
viz.plot_not_normalized_data_fh(for_features=True)
